# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Gustavo Oliveira
#
# Nome: Gabriela Duarte
#
# Nome: Vinicius Morales

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\guoli\OneDrive\Faculdades\Insper\Semestre 2\Ciencia dos dados\P1\Projeto-1-CDados

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'trabalho1bbb.gu.xlsx'

# %%
dados = pd.read_excel(filename)
filtra_linhas1 = dados['BBB 21'] == 'x'
filtra_linhas2 = dados['Outros BBB'] == 'x'
filtra_linhas3 = dados['irrelevantes'] == 'x'
train = dados.loc[:, ['Treinamento', 'BBB 21', 'Outros BBB', 'irrelevantes']]
train.head(5)
# Out:
#                                          Treinamento BBB 21 Outros BBB  \
# 0  flans, corre aqui! @gecychaves @meninodelll @m...    NaN        NaN
# 1  @m0m0v0gue sim \n\n#bbtvi2020 #followtrick #fo...    NaN        NaN
# 2  so conheço o 1 e 3 ent nao posso opinar\n\n#fo...    NaN        NaN
# 3  vou fazer meu msd de uma vez\n\n#follotrick #b...    NaN        NaN
# 4  legal as minhas favs 😍\nmas acho que vou de an...    NaN        NaN
#
#   irrelevantes
# 0            x
# 1            x
# 2            x
# 3            x
# 4            x

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test = test.loc[:, ['Teste', 'BBB 21', 'Outros BBB', 'irrelevantes']]
test.head(5)
# Out:
#                                                Teste BBB 21 Outros BBB  \
# 0  meu detox do twitter é ler os comentários da p...    NaN          x
# 1  de acordo com o site notícias da tv, a #globo ...    NaN        NaN
# 2  @webtvbrasileira\n\nassista #bigbrotherbrasil ...    NaN        NaN
# 3  @jkprities sim \n\n#bbtvi2020 #followtrick #fo...    NaN        NaN
# 4  "quem quer fica. quem não quer vai embora."\n ...      x        NaN
#
#   irrelevantes
# 0          NaN
# 1            x
# 2            x
# 3            x
# 4          NaN

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# Nossos dados são sobre o BBB, onde nós filtramos eles por 3 categorias, se o tweet é relacionado a BBB 21, outros BBBs e se o Tweet é relevante ou não.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
import re


def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    #import string
    punctuation = '\@\w+\s?|[\n!-,.:?;|]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    
    return text_subbed

for i in range(500):
    train.Treinamento[i] = cleanup(train.Treinamento[i].lower())

train
# Out:
#                                            Treinamento BBB 21 Outros BBB  \
# 0    flans corre aqui   a quixitagem ta fofona dema...    NaN        NaN
# 1    sim bbtvi2020 followtrick follotrick kpop kpop...    NaN        NaN
# 2    so conheço o 1 e 3 ent nao posso opinarfollotr...    NaN        NaN
# 3    vou fazer meu msd de uma vezfollotrick bbtvi r...    NaN        NaN
# 4    legal as minhas favs 😍mas acho que vou de anyf...    NaN        NaN
# ..                                                 ...    ...        ...
# 651  toda festa do líder a gent fica sabendo até os...      x        NaN
# 652  arthur brinca com caio: 'você me fez lembrar d...      x        NaN
# 653  rt @somosrepetidas: planta faz isso? #bbb21 #c...      x        NaN
# 654  falar do gil é  facil kkkk quero ver peitar el...    NaN        NaN
# 655  essa é nova, fiuk filho de roberto carlo e gló...      x        NaN
#
#     irrelevantes
# 0              x
# 1              x
# 2              x
# 3              x
# 4              x
# ..           ...
# 651          NaN
# 652          NaN
# 653          NaN
# 654          NaN
# 655          NaN
#
# [656 rows x 4 columns]

# %%
for i in range(len(test)):
    test['Teste'][i] = cleanup(train.Treinamento[i].lower())

test
# Out:
#                                                  Teste BBB 21 Outros BBB  \
# 0    flans corre aqui   a quixitagem ta fofona dema...    NaN          x
# 1    sim bbtvi2020 followtrick follotrick kpop kpop...    NaN        NaN
# 2    so conheço o 1 e 3 ent nao posso opinarfollotr...    NaN        NaN
# 3    vou fazer meu msd de uma vezfollotrick bbtvi r...    NaN        NaN
# 4    legal as minhas favs 😍mas acho que vou de anyf...      x        NaN
# ..                                                 ...    ...        ...
# 294  gilberto e juliette travam batalha e fãs do an...      x        NaN
# 295  rt  assim de saúde 🥺🪦🍒sarolffo bbb21 bigbrothe...      x        NaN
# 296  estou ignorando todos os meus compromissos de ...      x        NaN
# 297  de qual lado você está juliettefreire juliette...      x        NaN
# 298  avisei vcs sarah não ia acreditar na juliette ...      x        NaN
#
#     irrelevantes
# 0            NaN
# 1              x
# 2              x
# 3              x
# 4            NaN
# ..           ...
# 294          NaN
# 295          NaN
# 296          NaN
# 297          NaN
# 298          NaN
#
# [299 rows x 4 columns]

# %%
filtra_linhas1 = train['BBB 21'] == 'x'
tabelaBBB21 = train.loc[filtra_linhas1,['Treinamento']] # Tabela filtrada com apenas os dados relevantes de BBB21

filtra_linhas2 = train['Outros BBB'] == 'x'
tabela_outros = train.loc[filtra_linhas2,['Treinamento']] # Tabela filtrada com apenas os dados relevantes de Outros BBB

filtra_linhas3 = train['irrelevantes'] == 'x'
tabela_ir = train.loc[filtra_linhas3,['Treinamento']] # Tabela filtrada com apenas os dados relevantes de Irrelevantes

# %%
# Transformando as linhas dos DataFrames em arrays de strings
palavras_train_BBB21 = tabelaBBB21.values.tolist()
palavras_train_outros = tabela_outros.values.tolist()
palavras_train_ir = tabela_ir.values.tolist()

# %%
# Fazendo o join dos arrays em strings
palavras_train_BBB21 = ''.join(x for sub in palavras_train_BBB21 for x in sub)
palavras_train_outros = ''.join(x for sub in palavras_train_outros for x in sub)
palavras_train_ir = ''.join(x for sub in palavras_train_ir for x in sub)

# %%
palavras_train_BBB21 = palavras_train_BBB21.split()
serieBBB21 = pd.Series(palavras_train_BBB21)
tabela_absolute_BBB21 = serieBBB21.value_counts()
tabela_absolute_BBB21.head
# Out:
# <bound method NDFrame.head of e                   337
# bbb21               330
# bigbrotherbrasil    291
# a                   282
# o                   274
#                    ...
# jogo?                 1
# avisa...              1
# adolescência          1
# mermo                 1
# voltoooou             1
# Length: 3283, dtype: int64>

# %%
palavras_train_outros = palavras_train_outros.split()
serie_outros = pd.Series(palavras_train_outros)
tabela_absolute_outros = serie_outros.value_counts()
tabela_absolute_outros.head()
# Out:
# bigbrotherbrasil    13
# de                  13
# s21                 10
# big                 10
# brasil              10
# dtype: int64

# %%
palavras_train_ir = palavras_train_ir.split()
serie_ir = pd.Series(palavras_train_ir)
tabela_absolute_ir = serie_ir.value_counts()
tabela_absolute_ir.head()
len_palavras_train_ir = len(palavras_train_ir)

# %%
tabela_absolute_BBB21.sum()
# Out:
# 12463

# %%
tabela_absolute_outros.sum()
# Out:
# 339

# %%
tabela_absolute_ir.sum()
# Out:
# 827

# %%
tabela_absolute_BBB21
# Out:
# e                   337
# bbb21               330
# bigbrotherbrasil    291
# a                   282
# o                   274
#                    ...
# jogo?                 1
# avisa...              1
# adolescência          1
# mermo                 1
# voltoooou             1
# Length: 3283, dtype: int64

# %%
tabela_absolute_outros
# Out:
# bigbrotherbrasil    13
# de                  13
# s21                 10
# big                 10
# brasil              10
#                     ..
# d                    1
# clara                1
# paredão              1
# questões             1
# estratégias          1
# Length: 188, dtype: int64

# %%
tabela_absolute_ir
# Out:
# bbb21                        51
# bigbrotherbrasil             33
# kpop                         29
# redebbb                      26
# kpoptwitter                  21
#                              ..
# pagar                         1
# crash4                        1
# semana                        1
# https//tco/rumqu3frgoquer     1
# eliminadadobbb                1
# Length: 371, dtype: int64

# %%
# Probabilidades absolutas sem Laplace Smoothing
#probBBB = tabela_absolute_BBB21.sum()/(tabela_absolute_BBB21.sum()+tabela_absolute_outros.sum()+tabela_absolute_ir.sum())
#probOutros = tabela_absolute_outros.sum()/(tabela_absolute_BBB21.sum()+tabela_absolute_outros.sum()+tabela_absolute_ir.sum())
#probIr = tabela_absolute_ir.sum()/(tabela_absolute_BBB21.sum()+tabela_absolute_outros.sum()+tabela_absolute_ir.sum())

# %%
def laplace(palavra, dicionario):
    ocorrencias = dicionario[palavra] if palavra in dicionario else 0
    resultado = (ocorrencias + 1)/(dicionario.sum() + len(dicionario))
    
    return resultado

# %%
def classifica_frase(frase):
    probPalavraDadoBBB21 = 1
    probPalavraDadoOutros = 1
    probPalavraDadoIr = 1
    frase = cleanup(frase)
    palavras = frase.split(' ')
    for palavra in palavras:
        probPalavraDadoBBB21 *= laplace(palavra, tabela_absolute_BBB21)
        probPalavraDadoOutros *= laplace(palavra, tabela_absolute_outros)
        probPalavraDadoIr *= laplace(palavra, tabela_absolute_ir)
    
    if probPalavraDadoBBB21 > probPalavraDadoIr and probPalavraDadoBBB21 > probPalavraDadoOutros:
        return 'BBB21'
    elif probPalavraDadoIr > probPalavraDadoBBB21 and probPalavraDadoIr > probPalavraDadoOutros:
        return 'Irrelevantes'
    elif probPalavraDadoOutros > probPalavraDadoBBB21 and probPalavraDadoOutros > probPalavraDadoIr:
        return 'Outros BBB'

# %%
classifica_frase('bbb20')
# Out:
# 'Outros BBB'

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
test_split = []
for frase in test['Teste']:
    frase = frase.split()
    test_split.append(frase)
test_split
# Out:
# [['flans',
#   'corre',
#   'aqui',
#   'a',
#   'quixitagem',
#   'ta',
#   'fofona',
#   'demaixxxx',
#   'nesse',
#   'bbb',
#   'bigbrotherbrasil',
#   'bbb21'],
#  ['sim',
#   'bbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['so',
#   'conheço',
#   'o',
#   '1',
#   'e',
#   '3',
#   'ent',
#   'nao',
#   'posso',
#   'opinarfollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f',
#   'https//tco/z9qvk7i9uz'],
#  ['vou',
#   'fazer',
#   'meu',
#   'msd',
#   'de',
#   'uma',
#   'vezfollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasil',
#   'https//tco/r681ggnj9f'],
#  ['legal',
#   'as',
#   'minhas',
#   'favs',
#   '😍mas',
#   'acho',
#   'que',
#   'vou',
#   'de',
#   'anyfollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasil',
#   'https//tco/w6xree3hms',
#   'https//tco/eeqqokfln9'],
#  ['bbb21',
#   'veja',
#   'como',
#   'a',
#   'rede',
#   'globo',
#   'manipula',
#   'as',
#   'notícias',
#   'a',
#   'favor',
#   'de',
#   'seus',
#   'interesses',
#   '🐀',
#   'redeglobo',
#   'fantastico',
#   'jornalnacional',
#   'encontro',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'bbb',
#   'bbb2021',
#   'paredaobbb',
#   '__',
#   'documentário',
#   'da',
#   'bbc',
#   'https//tco/nvtkqz2ptq'],
#  ['quemfollowtrick',
#   'sdv',
#   'bbtvi2020',
#   'bbb2021',
#   'afazenda',
#   'redebbb',
#   'bbb21',
#   'redebbb21',
#   'sdv',
#   'falandodebbb',
#   'bigbrotherbrasil',
#   'kpophttps//tco/sroa4gkldg'],
#  ['sigam',
#   'nosso',
#   'instagram',
#   'e',
#   'fiquem',
#   'por',
#   'dentro',
#   'de',
#   'tudo',
#   'que',
#   'acontece',
#   'no',
#   'bbb21',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'feedbbb',
#   'bbbaeliminacao',
#   'bbbaovivo',
#   'paredaobbb',
#   'bigbrotherbrasil',
#   'redeglobo',
#   'sdv',
#   'https//tco/5mfq3teo8s'],
#  ['sigam',
#   'nosso',
#   'instagram',
#   'e',
#   'fiquem',
#   'por',
#   'dentro',
#   'de',
#   'tudo',
#   'que',
#   'acontece',
#   'no',
#   'bbb21',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'feedbbb',
#   'bbbaeliminacao',
#   'bbbaovivo',
#   'paredaobbb',
#   'bigbrotherbrasil',
#   'redeglobo',
#   'sdv',
#   'https//tco/mmkch6eu4p'],
#  ['sigam',
#   'nosso',
#   'instagram',
#   'e',
#   'fiquem',
#   'por',
#   'dentro',
#   'de',
#   'tudo',
#   'que',
#   'acontece',
#   'no',
#   'bbb21',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'feedbbb',
#   'bbbaeliminacao',
#   'bbbaovivo',
#   'paredaobbb',
#   'bigbrotherbrasil',
#   'redeglobo',
#   'sdv',
#   'https//tco/amz2xs5dzo'],
#  ['eu',
#   'aq',
#   'admbigbrotherbrasil',
#   'followtrick',
#   'bbtvi',
#   'bbb21',
#   'bbb2021',
#   'bbb',
#   'https//tco/rumqu3frgo'],
#  ['quer',
#   'nudes',
#   'ou',
#   'vídeoschama',
#   'na',
#   'dm',
#   'sigiloajudo',
#   'na',
#   'siririca',
#   'pintosawards',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bundaawards',
#   'juliettefreire',
#   'gozar',
#   'gozo',
#   'gozando',
#   'tesão',
#   'safada',
#   'projota',
#   'gil',
#   'sarah',
#   'fiuk'],
#  ['só',
#   'para',
#   'lembrar',
#   'a',
#   'todosdar',
#   'rt',
#   'não',
#   'significa',
#   'endossar',
#   'o',
#   'que',
#   'está',
#   'escrito',
#   'ou',
#   'sendo',
#   'mostradoeu',
#   'dou',
#   'rt',
#   'quando',
#   'concordo',
#   'e',
#   'também',
#   'quando',
#   'não',
#   'concordo',
#   'ou',
#   'fico',
#   'indignadort',
#   'serve',
#   'pra',
#   'mostrar',
#   'o',
#   'melhor',
#   'e',
#   'o',
#   'pior',
#   'das',
#   'pessoasbbb',
#   'bbb21',
#   'bbb2021',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother'],
#  ['😘',
#   'inveja',
#   'amore',
#   'joga',
#   'na',
#   'linha',
#   'do',
#   'tempo',
#   'followtrick',
#   'sdv',
#   'bbtvi2020',
#   'bbb2021',
#   'afazenda',
#   'redebbb',
#   'bbb21',
#   'redebbb21',
#   'sdv',
#   'falandodebbb',
#   'bigbrotherbrasil',
#   'kpophttps//tco/sroa4gkldg'],
#  ['não',
#   'já',
#   'termineinamjoon',
#   'followtrick',
#   'kpop',
#   'dispatch',
#   'dispatchcouples',
#   'dispatchkorea',
#   'bbb21',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'https//tco/mepaqmnbjf'],
#  ['aparelhobbb21',
#   'followtrick',
#   'follotrick',
#   'bbtvi',
#   'rosmello',
#   'bbb2021',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'bbb',
#   'bigbrotherbrasil',
#   'https//tco/wdb5ax5hjr'],
#  ['use',
#   'o',
#   'picpay',
#   'para',
#   'pagar',
#   'amigos',
#   'boletos',
#   'recarregar',
#   'o',
#   'celular',
#   'steam',
#   'e',
#   'muito',
#   'mais',
#   'ao',
#   'criar',
#   'sua',
#   'conta',
#   'insira',
#   'o',
#   'meu',
#   'código',
#   'f2nycu',
#   'e',
#   'ganhe',
#   'r10',
#   'para',
#   'utilizar',
#   'https//tco/n4bi1fgi4bpicpay',
#   'bbb21',
#   'redebbb',
#   'patrocinadoroficial',
#   'bigbrotherbrasil'],
#  ['podebbb2021',
#   'bbb21',
#   'bbbeliminacao',
#   'bbtvi',
#   'redebbb',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/uh8vwstal1'],
#  ['todos',
#   'menos',
#   'o',
#   '2',
#   'q',
#   'nao',
#   'conhecofollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f',
#   'https//tco/srfnob7rlo'],
#  ['amigos',
#   'boa',
#   'noite',
#   'aqui',
#   'já',
#   'são',
#   '427',
#   'vou',
#   'cair',
#   'nos',
#   'braços',
#   'de',
#   'morpheusbeijinhosfestadolider',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['isso',
#   'as',
#   'tem',
#   'que',
#   'pegar',
#   '10k',
#   'de',
#   'view',
#   'por',
#   'deusjenniejenniegdragon',
#   'gdragon',
#   'follotrick',
#   'bbtvi',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'rosmello',
#   'bbbb21',
#   'bigbrotherbrasil',
#   'exrosmello',
#   'https//tco/ng0kdvx4bp'],
#  ['💥',
#   'bbb',
#   '21',
#   'playlist',
#   'projota',
#   'só',
#   'track',
#   'as',
#   'melhores',
#   'tracks',
#   'do',
#   'bbb',
#   'https//tco/nxp1ckogow',
#   'bigbrotherbrasil\u200b',
#   'redebbb\u200b',
#   'bbb\u200b',
#   'bbb\u200b',
#   '21',
#   'redebbb\u200b',
#   'kaioalmeida\u200b',
#   'bbb19\u200b',
#   'bigbrotherbrasil\u200b',
#   'gshow\u200b',
#   'amor\u200b',
#   'riodejaneiro\u200b',
#   'instagram\u200b',
#   'brasil\u200b',
#   'redeglobo\u200b',
#   'tbt\u200b',
#   'globo\u200b',
#   'boanoite'],
#  ['deu',
#   'até',
#   'saudades',
#   'do',
#   'carnaval',
#   'bigbrotherbrasil',
#   'bigbrotherbrasil21',
#   'bbb',
#   'bbb21',
#   'karolconká',
#   'gaeldisouza',
#   'morenatropicana',
#   'jbboninho',
#   'redeglobo',
#   'globoplay',
#   'eliminadadobbb',
#   'globo',
#   'gshow',
#   'realityshow',
#   'bbbaovivo',
#   'bbb24horas',
#   'redebbb',
#   'eliminaçãobbb',
#   'noticias',
#   'twitter',
#   'https//tco/akdwd1lbeo'],
#  ['faço',
#   '14',
#   'esse',
#   'mêsbbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['fiz',
#   'um',
#   'tt',
#   'só',
#   'para',
#   'bater',
#   'boca',
#   'kkkl',
#   'redebbb',
#   'bigbrotherbrasil',
#   'teamjuliettefreire'],
#  ['tadinha',
#   'dessa',
#   'criança',
#   'mds',
#   'follotrick',
#   'bbtvi',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'rosmello',
#   'bbbb21',
#   'kpop',
#   'bigbrotherbrasil',
#   'exrosmello',
#   'https//tco/9rcctn8oig'],
#  ['moçe',
#   'pq',
#   'vc',
#   'faz',
#   'isso',
#   'nao',
#   'daaafollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f',
#   'https//tco/unzxmqay4g'],
#  ['sim',
#   'bbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['bbb21',
#   'veja',
#   'como',
#   'a',
#   'rede',
#   'globo',
#   'manipula',
#   'as',
#   'notícias',
#   'a',
#   'favor',
#   'de',
#   'seus',
#   'interesses',
#   '🐀',
#   'redeglobo',
#   'fantastico',
#   'jornalnacional',
#   'encontro',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'bbb',
#   'bbb2021',
#   'paredaobbb',
#   '_',
#   'documentário',
#   'da',
#   'bbc',
#   'https//tco/nvtkqz2ptq'],
#  ['nem',
#   'uso',
#   'meu',
#   'insta',
#   '/followtrick',
#   'bigbrotherbrasil',
#   '로제',
#   'rosé',
#   'ontheground',
#   'followforfolloback',
#   'bbb21',
#   'truebeauty',
#   'https//tco/zqmpakfryh'],
#  ['valentina',
#   'fez',
#   'cocô',
#   'nas',
#   'calças',
#   'de',
#   'novo',
#   'márcia',
#   'acreditaainda',
#   'bem',
#   'que',
#   'final',
#   'de',
#   'semana',
#   'o',
#   'pai',
#   'que',
#   'cuida',
#   'amém',
#   'senhor',
#   'hahaahahahahahaharedebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea',
#   'https//tco/4sgaczogwi'],
#  ['rt',
#   'sem',
#   'filtro',
#   'ou',
#   'mimimi',
#   'bbb10',
#   'dourado',
#   'esse',
#   'filme',
#   'mudou',
#   'meu',
#   'conceito',
#   'de',
#   'horrível',
#   '😂😂😂😂bbb21',
#   'bigbrotherbra…'],
#  ['vídeo',
#   'novo',
#   'no',
#   'canalbora',
#   'lá',
#   'deixar',
#   'o',
#   'like',
#   'e',
#   'se',
#   'inscreva',
#   '🥺🥺🥺https//tco/sq7kwazltetwitchbrasil',
#   'gameplay',
#   'crashbandicoot4',
#   'ps5',
#   'youtube',
#   'ps5share',
#   'crashbandicoot',
#   'games',
#   'crash4',
#   'twitchaffiliate',
#   'bigbrotherbrasil',
#   'designgrafico',
#   'celular',
#   'gaymer',
#   'felizpascoa'],
#  ['sim',
#   'bbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['cachorrobbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['nao',
#   'sou',
#   'mt',
#   'fa',
#   'de',
#   'feijoadafollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasil',
#   'https//tco/r681ggnj9f'],
#  ['não',
#   'gostofollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasil',
#   'https//tco/w6xree3hms'],
#  ['1',
#   'e',
#   '4bbtvi2020',
#   'followtrick',
#   'follotrick',
#   'kpop',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'julliete',
#   'kpop',
#   'paredao',
#   'bbb21',
#   'https//tco/fh4hrhfrhe'],
#  ['nao',
#   'da',
#   'simplesmente',
#   'nao',
#   'dafollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f',
#   'https//tco/5kzgveokgt'],
#  ['doramafollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f'],
#  ['chronossaurusfollotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasilhttps//tco/r681ggnj9f',
#   'https//tco/bbkzuue2qa'],
#  ['rt',
#   'ainda',
#   'sobre',
#   'o',
#   'bbb21redebbb',
#   'bigbrotherbrasil',
#   'https//tco/3zotllt2a8'],
#  ['você',
#   'é',
#   'machista',
#   'significado',
#   'e',
#   'psicologia',
#   'assista',
#   'https//tco/mgsbu7sy7psiga',
#   'machista',
#   'machismo',
#   'sororidade',
#   'bigbrotherbrasil',
#   'redebbb',
#   'feminismo',
#   'feministas',
#   'lacração',
#   'scruffbrasil',
#   'lgbtqsnotopo',
#   'gaybrasil',
#   'educacao',
#   'palestra',
#   'youtubebr',
#   'empoderamento',
#   'https//tco/x4azohhpbs'],
#  ['meudeus',
#   'que',
#   'coisa',
#   'linda',
#   'follotrick',
#   'bbtvi',
#   'rosmello',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'dispatch',
#   'dispatchkorea',
#   'bbb21',
#   'bbbb21',
#   'bbb221',
#   'bigbrotherbrasil',
#   'https//tco/r681ggnj9f'],
#  ['infelizmente',
#   'já',
#   'bbb21',
#   'followtrick',
#   'follotrick',
#   'bbtvi',
#   'rosmello',
#   'bbb2021',
#   'kpop',
#   'redebbb',
#   'kpoptwitter',
#   'bbb',
#   'bigbrotherbrasil',
#   'https//tco/ptagfdvyu6'],
#  ['só',
#   'musicão',
#   'na',
#   'festa',
#   'do',
#   'fiuk',
#   '🎶🎶🎶festadolider',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebbb',
#   'falandodebbb',
#   'reality'],
#  ['o',
#   'rodolfo',
#   'não',
#   'assume',
#   'que',
#   'tá',
#   'muito',
#   'afim',
#   'da',
#   'kkkkk',
#   'agora',
#   'na',
#   'festa',
#   'falando',
#   'que',
#   'ela',
#   'tem',
#   'o',
#   'cabelo',
#   'bonito',
#   'ele',
#   'tá',
#   'reparando',
#   'muito',
#   'em',
#   '😆😆😆😆redebbb',
#   'bigbrotherbrasil',
#   'bbb21',
#   'multishow'],
#  ['o',
#   'fiuk',
#   'foi',
#   'no',
#   'quarto',
#   'tirar',
#   'a',
#   'roupa',
#   'que',
#   'a',
#   'produção',
#   'fez',
#   'pra',
#   'ele',
#   'pra',
#   'botar',
#   'uma',
#   'bermuda',
#   'conforto',
#   'né',
#   'mores',
#   'festadolider',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['que',
#   'festa',
#   'é',
#   'essa',
#   'bbb21',
#   'bigbrotherbrasil',
#   'fiuk',
#   'https//tco/70di3vhmem'],
#  ['só',
#   'pra',
#   'entender',
#   'aqui',
#   'em',
#   'um',
#   'paredão',
#   'desse',
#   'quem',
#   'sai',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bbb',
#   'foragilberto',
#   'forajuliete',
#   'foraarthur',
#   'foraviihtube',
#   'foracarladiaz'],
#  ['uma',
#   'coisa',
#   'é',
#   'certa',
#   'gilberto',
#   'segurou',
#   'o',
#   'rojão',
#   'de',
#   'sarah',
#   'amigo',
#   'é',
#   'amigo',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['rt',
#   'na',
#   'ana',
#   'maria',
#   'projota',
#   'revela',
#   'que',
#   'mulher',
#   'foi',
#   'contra',
#   'participação',
#   'no',
#   'bbb21',
#   'e',
#   'em',
#   'lágrimas',
#   'assume',
#   'sobre',
#   'decepção',
#   '-',
#   'https//tc…'],
#  ['meu',
#   'deus',
#   'que',
#   'linda',
#   'que',
#   'a',
#   'ju',
#   'tá',
#   'meu',
#   'caraiiiiredebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'paredaobbb',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea',
#   'https//tco/luxoiiigmx'],
#  ['excelente',
#   'jogadora',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'https//tco/k2cvlaba0z'],
#  ['rt',
#   'gente',
#   'tá',
#   'tocando',
#   'tenho',
#   'um',
#   'coração',
#   'com',
#   'buraquinhooo',
#   'minha',
#   'infância',
#   'está',
#   'viva',
#   'redebbb',
#   'bigbrotherbrasil',
#   'festadolid…'],
#  ['vazou',
#   'o',
#   'cardápio',
#   'da',
#   'festa',
#   'do',
#   'líder',
#   'hoje',
#   'bbb21',
#   'festadolider',
#   'bigbrotherbrasil',
#   'https//tco/jc6dg9b8rz'],
#  ['a',
#   'juliette',
#   'tem',
#   'tanto',
#   'conhecimento',
#   'das',
#   'coisas',
#   'que',
#   'fala',
#   'e',
#   'de',
#   'suas',
#   'atitudes',
#   'que',
#   'nem',
#   'pestaneja',
#   'quando',
#   'fala',
#   'é',
#   'classe',
#   'educação',
#   'e',
#   'inteligência',
#   'pra',
#   'conversar',
#   'não',
#   'precisa',
#   'gritar',
#   'precisa',
#   'argumentarteamjuliette',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['ju',
#   'tá',
#   'usando',
#   'a',
#   'tática',
#   'dos',
#   'cachorros',
#   'kkkkkk',
#   'quando',
#   'deitam',
#   'em',
#   'uma',
#   'briga',
#   'tão',
#   'querendo',
#   'cessar',
#   'redebbb',
#   'bbb',
#   'bigbrotherbrasil'],
#  ['gente',
#   'juliette',
#   'com',
#   '1',
#   'mês',
#   'e',
#   'alguns',
#   'dias',
#   'de',
#   'big',
#   'brother',
#   'ganhou',
#   '14',
#   'milhões',
#   'de',
#   'seguidores',
#   'o',
#   'favoritismo',
#   'dela',
#   'e',
#   'surreal',
#   '❤️bigbrotherbrasil',
#   'juliettefreire'],
#  ['bbb21',
#   'bigbrotherbrasil',
#   'gshow',
#   'mais',
#   'não',
#   'precisa',
#   'tentar',
#   'queimar',
#   'elaela',
#   'juliette',
#   'se',
#   'queima',
#   'sozinha',
#   'basta',
#   'a',
#   'edição',
#   'mostrar',
#   'as',
#   'cenas',
#   'dela',
#   'sem',
#   'cortefalasolhares',
#   'intenção',
#   'e',
#   'malícia',
#   'que',
#   'ela',
#   'sai',
#   'de',
#   'lá',
#   'no',
#   'próximo',
#   'paredão',
#   'rsrsrssrs'],
#  ['porque',
#   'ela',
#   'sabe',
#   'que',
#   'o',
#   'gil',
#   'não',
#   'se',
#   'aguenta',
#   'que',
#   'ele',
#   'é',
#   'esquentado',
#   'então',
#   'ela',
#   'plantando',
#   'isso',
#   'ela',
#   'vai',
#   'puxar',
#   'briga',
#   'com',
#   'ele',
#   'ele',
#   'vai',
#   'acabar',
#   'apontando',
#   'o',
#   'dedo',
#   'na',
#   'cara',
#   'dela',
#   'e',
#   'ela',
#   'vai',
#   'sair',
#   'dizendo',
#   'pra',
#   'casa',
#   'toda',
#   'que',
#   'ele',
#   'usou',
#   'uma',
#   'fraqueza',
#   'dela',
#   'pra',
#   'ela',
#   'sair',
#   'da',
#   'casabbb21',
#   'bigbrotherbrasil'],
#  ['tocando',
#   'bad',
#   'romance',
#   'meu',
#   'deus',
#   'como',
#   'que',
#   'não',
#   'canta',
#   'bbb21',
#   'bigbrotherbrasil',
#   'festadolider'],
#  ['sarah',
#   'diz',
#   'para',
#   'gilberto',
#   'é',
#   'só',
#   'manter',
#   'a',
#   'boa',
#   'vizinhança',
#   'que',
#   'vamos',
#   'longe',
#   'na',
#   'pista',
#   'de',
#   'dança',
#   'da',
#   'festa',
#   'do',
#   'líder',
#   'da',
#   'semana',
#   'fhttps//tco/jmjum65v9jbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['bbb21',
#   'gilberto',
#   'desabafa',
#   'e',
#   'diz',
#   'que',
#   'não',
#   'serve',
#   'para',
#   'chegar',
#   'na',
#   'final',
#   '-',
#   'cada',
#   'semana',
#   'eu',
#   'só',
#   'faço',
#   'é',
#   'me',
#   'enterrar',
#   'mais',
#   '-',
#   'bigbrotherbrasil',
#   'bigbrotherbrasil21',
#   'giberto',
#   'gil',
#   'globo',
#   'realityshow',
#   '-',
#   'https//tco/8s0rqfkeal'],
#  ['acho',
#   'que',
#   'as',
#   'pessoas',
#   'estão',
#   'subestimando',
#   'a',
#   'inteligência',
#   'do',
#   'soacho',
#   'e',
#   'como',
#   'a',
#   'ana',
#   'maria',
#   'disse',
#   'hj',
#   'observe',
#   'as',
#   'pessoas',
#   'que',
#   'estão',
#   'ao',
#   'seu',
#   'lado',
#   'mas',
#   'observe',
#   'quem',
#   'são',
#   'as',
#   'leais',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['eu',
#   'hoje',
#   'vou',
#   'dormir',
#   'cedo',
#   'não',
#   'vou',
#   'ficar',
#   'até',
#   'tarde',
#   'vendo',
#   'bbbnotícias',
#   'tá',
#   'rolando',
#   'treta',
#   'entre',
#   'gilberto',
#   'e',
#   'julieteeu',
#   'de',
#   'novo',
#   '🤡bbb21',
#   'bigbrotherbrasil',
#   'teamjuliette'],
#  ['gentem',
#   'me',
#   'desculpem',
#   'mas',
#   'não',
#   'largo',
#   'a',
#   'mão',
#   'do',
#   'gil',
#   'e',
#   'da',
#   'sarah',
#   'gosto',
#   'davisao',
#   'de',
#   'jogo',
#   'deles',
#   'e',
#   'da',
#   'forma',
#   'leve',
#   'e',
#   'bem',
#   'humorada',
#   'pronto',
#   'falei',
#   'bbb21',
#   'bigbrotherbrasil',
#   'gildovigor',
#   'ssarahandrade'],
#  ['vídeos',
#   'bbb',
#   'antiga',
#   'dr',
#   'entre',
#   'juliette',
#   'e',
#   'lumena',
#   'segue',
#   'repercutindo',
#   'na',
#   'casa',
#   'do',
#   'brep',
#   'gshow/bbbvote',
#   'também',
#   'na',
#   'enquete',
#   'bbbhttps//tco/ylroj7rga2bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['sobre',
#   'só',
#   '1',
#   'coisa',
#   'a',
#   'declarar',
#   'na',
#   'vida',
#   'real',
#   'como',
#   'é',
#   'mais',
#   'fácil',
#   'ser',
#   'ator',
#   'das',
#   'suas',
#   'próprias',
#   'verdades',
#   'né',
#   'maisvocê',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['juliette',
#   'é',
#   'muito',
#   'inteligente',
#   'mano',
#   'por',
#   'isso',
#   'consegue',
#   'uma',
#   'legião',
#   'de',
#   'trouxa',
#   'aqui',
#   'fora',
#   'sempre',
#   'remoendo',
#   'assuntos',
#   'em',
#   'que',
#   'ela',
#   'saiu',
#   'sensata',
#   'ou',
#   'vítima',
#   'e',
#   'não',
#   'deixa',
#   'as',
#   'pessoas',
#   'se',
#   'defender',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['fechadão',
#   'com',
#   'gilberto',
#   'o',
#   'rei',
#   'do',
#   'entretenimento',
#   '♥️bbb21',
#   'bigbrotherbrasil'],
#  ['nunca',
#   'mais',
#   'ouvirei',
#   'muleque',
#   'de',
#   'vila',
#   '💔bagui',
#   'dodói',
#   'se',
#   'decepcionar',
#   'assim',
#   '😟hipocrita',
#   'foraprojota',
#   'juliette',
#   'bbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'gil',
#   'paredaobbb'],
#  ['após',
#   'discussão',
#   'com',
#   'sister',
#   'gilberto',
#   'chora',
#   'na',
#   'academia',
#   'do',
#   'bbb21',
#   'após',
#   'a',
#   'longa',
#   'discussão',
#   'juliette',
#   'pede',
#   'um',
#   'abra�https//tco/rqnvvojplibbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['lumena',
#   'já',
#   'era',
#   'ruim',
#   'desde',
#   'o',
#   'começo',
#   'do',
#   'programa',
#   'agora',
#   'querem',
#   'fazer',
#   'que',
#   'a',
#   'juliette',
#   'que',
#   'fez',
#   'ela',
#   'ficar',
#   'com',
#   'imagem',
#   'de',
#   'mal',
#   'ah',
#   'vai',
#   'se',
#   'fuder',
#   'redebbb',
#   'bbb21',
#   'bbb',
#   'bigbrotherbrasil'],
#  ['bbb21',
#   'gilberto',
#   'compara',
#   'homofobia',
#   'ao',
#   'olhar',
#   'de',
#   'juliette',
#   'freire',
#   'pro',
#   'fiuk',
#   'fumandoeuliette',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'freirejuliette',
#   'voltou',
#   'dia',
#   'do',
#   'fã',
#   'carla',
#   'diazhttps//tco/rfsgbepowj',
#   '-'],
#  ['ah',
#   'gente',
#   'me',
#   'inclui',
#   'nesse',
#   'bonde',
#   'quero',
#   'ser',
#   'amiga',
#   'de',
#   'vcs',
#   'hahaharedebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'paredaobbb',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea',
#   'https//tco/swqhypyvrg'],
#  ['é',
#   'verdade',
#   'que',
#   'já',
#   'conversou',
#   'com',
#   'o',
#   'eliminado',
#   'da',
#   'semana',
#   'que',
#   'vem',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['juliette',
#   'não',
#   'está',
#   'excluindo',
#   'gildovigor',
#   'e',
#   'sarah',
#   'ela',
#   'apenas',
#   'abriu',
#   'o',
#   'olho',
#   'errada',
#   'não',
#   'tá',
#   'foraarthur',
#   'bbb21',
#   'bbb21carla',
#   'bigbrotherbrasil',
#   'anamariabraga'],
#  ['a',
#   'sarah',
#   'chorando',
#   'pq',
#   'lá',
#   'no',
#   'bbb',
#   'pq',
#   'as',
#   'pessoas',
#   'se',
#   'aproximam',
#   'é',
#   'no',
#   'dia',
#   'seguinte',
#   'some',
#   'mas',
#   'num',
#   'jogo',
#   'é',
#   'estratégia',
#   'pior',
#   'sou',
#   'eu',
#   'que',
#   'passo',
#   'por',
#   'isso',
#   'na',
#   'vida',
#   'kkkkk',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['foto',
#   'atualizada',
#   '🗣️❤️bbb21',
#   'teamcamilla',
#   'bigbrotherbrasil',
#   'https//tco/aykf8fp438'],
#  ['caio',
#   'e',
#   'viihtube',
#   'são',
#   'os',
#   'mais',
#   'falsos',
#   'bbbbbb21',
#   'festadofiuk',
#   'festasdolider',
#   'bigbrotherbrasil',
#   'caiofalso',
#   'viihfalsa'],
#  ['viih',
#   'tube',
#   'dispara',
#   'sobre',
#   'sister',
#   'do',
#   'bbb21',
#   'após',
#   'queridômetro',
#   'quem',
#   'está',
#   'sendo',
#   'c',
#   'viih',
#   'tube',
#   'dispara',
#   'sobre',
#   'sister',
#   'do',
#   'bbb21',
#   'após',
#   'quehttps//tco/iiy3mpdxo8bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['até',
#   'quando',
#   'a',
#   'carla',
#   'diaz',
#   'vai',
#   'se',
#   'humilhar',
#   'meu',
#   'povo',
#   '😡🤦\u200d♂️https//tco/jd3ugqd4iabbb21',
#   'bbb',
#   'bigbrotherbrasil',
#   'tvglobo',
#   'realityshow',
#   'carladiaz',
#   'arthurpicoli',
#   'relacionamento',
#   'exnamorada',
#   'globo',
#   'rj',
#   'sp',
#   'famosos'],
#  ['pelo',
#   'amor',
#   'de',
#   'deus',
#   'que',
#   'vida',
#   'é',
#   'essa',
#   'que',
#   'eu',
#   'tô',
#   'seguindo0310',
#   'da',
#   'madrugada',
#   'e',
#   'eu',
#   'vendo',
#   'festa',
#   'de',
#   'bbb',
#   'amanhã',
#   'tenho',
#   'mil',
#   'coisas',
#   'pra',
#   'fazer',
#   'e',
#   'tô',
#   'aqui',
#   'fingindo',
#   'que',
#   'não',
#   'existe',
#   'o',
#   'amanhã',
#   'festadolider',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['ai',
#   'gente',
#   'eles',
#   'tão',
#   'cantando',
#   'engenheiros',
#   '🥺🥺🥺🥺bbb21',
#   'bigbrotherbrasil',
#   'festadolider'],
#  ['a',
#   'risada',
#   'do',
#   'é',
#   'muito',
#   'gostosinha',
#   'de',
#   'escutar',
#   '😍',
#   'bigbrotherbrasil',
#   'bbb21',
#   'redebbb'],
#  ['rapaz',
#   'ta',
#   'nogento',
#   'ja',
#   'a',
#   'torcida',
#   'do',
#   'atacando',
#   'a',
#   'todo',
#   'custo',
#   'usando',
#   'palavras',
#   'e',
#   'termos',
#   'que',
#   'nao',
#   'condizem',
#   'com',
#   'a',
#   'mesma',
#   'e',
#   'sim',
#   'com',
#   'ele',
#   'olhem',
#   'o',
#   'umbigo',
#   'de',
#   'vcs',
#   'bbb21',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'bigbrotherbrasil2021'],
#  ['viih',
#   'tube',
#   'avisa',
#   'joão',
#   'luiz',
#   'e',
#   'juliette',
#   'sobre',
#   'brother',
#   'se',
#   'forçar',
#   'eu',
#   'não',
#   'tenho',
#   'p',
#   'no',
#   'banheiro',
#   'da',
#   'casa',
#   'do',
#   'bbb21',
#   'joão',
#   'luiz',
#   'está',
#   'tohttps//tco/vwimjumzczbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['gil',
#   'ta',
#   'perdido',
#   'no',
#   'jogo',
#   'alguem',
#   'precisa',
#   'ajudar',
#   'ele',
#   'a',
#   'se',
#   'reencontrar',
#   'pela',
#   'mor',
#   'de',
#   'deus',
#   'ele',
#   'é',
#   'um',
#   'fofo',
#   '🤧🤧🤧🤧❤',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['bigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'agora',
#   'o',
#   'arthur',
#   'agora',
#   'a',
#   'carla',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'chorou',
#   'camilla',
#   'e',
#   'juliette',
#   'https//tco/8jssrj7cbl'],
#  ['frase',
#   'da',
#   'noite',
#   'por',
#   'eu',
#   'quero',
#   'que',
#   'voçê',
#   'se',
#   'foda',
#   'e',
#   'minha',
#   'alfaçe',
#   'cresca',
#   '🤣🤣bbb21',
#   'bbb',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'bastião'],
#  ['teste',
#   'de',
#   'popularidade',
#   'pra',
#   'quem',
#   'vai',
#   'sua',
#   'torcida',
#   '💬🔁❤gil',
#   'sarah',
#   'juliettebbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'https//tco/6akxjadwhl'],
#  ['conversar',
#   'com',
#   'a',
#   'juliette',
#   'não',
#   'é',
#   'fácil',
#   'bigbrotherbrasil',
#   'bbb21'],
#  ['bbb21',
#   'gilberto',
#   'compara',
#   'homofobia',
#   'ao',
#   'olhar',
#   'de',
#   'juliette',
#   'freire',
#   'pro',
#   'fiuk',
#   'fumandoeuliette',
#   'globolixo',
#   'o',
#   'choro',
#   'é',
#   'livre',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'https//tco/rfsgbepowj'],
#  ['rt',
#   'a',
#   'juliettecampea',
#   'bebendo',
#   'o',
#   'gil',
#   'como',
#   'café',
#   'passado',
#   'não',
#   'tem',
#   'preçojuliettecampeã',
#   'juliettefreire',
#   'bbb21',
#   'bbb2021',
#   'bigbrother20…'],
#  ['tá',
#   'nítido',
#   'que',
#   'o',
#   'arthur',
#   'não',
#   'quer',
#   'mais',
#   'nada',
#   'com',
#   'a',
#   'carlaredebbb',
#   'bbb21',
#   'bigbrother',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'carladiaz'],
#  ['caio',
#   'caio',
#   'o',
#   'assunto',
#   'tava',
#   'encerrado',
#   'manco',
#   'do',
#   'caralhoredebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'paredaobbb',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea'],
#  ['o',
#   'bom',
#   'do',
#   'gil',
#   'nas',
#   'festas',
#   'é',
#   'que',
#   'ele',
#   'é',
#   'bem',
#   'liberto',
#   'solto',
#   'alegre',
#   'dança',
#   'canta',
#   'bebe',
#   'etc',
#   'me',
#   'vi',
#   'nele',
#   'nessas',
#   'horas',
#   'na',
#   'balada',
#   'rsrsrs',
#   'sdd',
#   'bbb21',
#   'bigbrotherbrasil',
#   'gil',
#   'gay'],
#  ['assista', 'bigbrotherbrasil', 'pelo', 'globoplay', 'https//tco/y1vcizutgo'],
#  ['o',
#   'leva',
#   'da',
#   'sarah',
#   'é',
#   'assimdiscordou',
#   'de',
#   'mim',
#   '=',
#   'estou',
#   'desconfiandobbb21',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['a',
#   'edição',
#   'hoje',
#   'desfavorecendo',
#   'juliette🤔🤔🤔',
#   'será',
#   'que',
#   'temos',
#   'um',
#   'novo',
#   'enredo',
#   'vindo',
#   'aíbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['que',
#   'que',
#   'o',
#   'gil',
#   'tá',
#   'arrumando',
#   'genteredebbb',
#   'bbb',
#   'bigbrotherbrasil'],
#  ['então',
#   'quer',
#   'dizer',
#   'q',
#   'aquele',
#   'alvoroço',
#   'todo',
#   'foi',
#   'pq',
#   'a',
#   'juliette',
#   'sentoubbb21',
#   'bigbrotherbrasil',
#   'redebbb',
#   'juliettefreire'],
#  ['olha',
#   'a',
#   'julliete',
#   'kakakakakak',
#   'mano',
#   'essa',
#   'mulher',
#   'é',
#   'rasteira',
#   'demais',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['bbb21',
#   'irmã',
#   'de',
#   'gil',
#   'não',
#   'se',
#   'agra',
#   'com',
#   'cenas',
#   'do',
#   'reality',
#   'e',
#   'dispara',
#   '-',
#   'por',
#   'mim',
#   'gilberto',
#   'sairia',
#   'dessa',
#   'casa',
#   'agora',
#   'mesmo',
#   '-',
#   'bigbrotherbrasil',
#   'bigbrotherbrasil21',
#   'globo',
#   'polêmicas',
#   'realityshow',
#   '-',
#   'https//tco/ueam58eeuc'],
#  ['quero',
#   'saber',
#   'quando',
#   'esse',
#   'efeito',
#   'manada',
#   'contra',
#   'falsidade',
#   'vai',
#   'ir',
#   'pra',
#   'cima',
#   'da',
#   'vih',
#   'cuspe',
#   'bbb21',
#   'bigbrotherbrasil',
#   'foracarladiaz',
#   'teamjuliette',
#   'teamgil',
#   'teamsarah'],
#  ['sarah',
#   'chamando',
#   'juliette',
#   'para',
#   'dormir',
#   'na',
#   'cama',
#   'com',
#   'ela',
#   'é',
#   'juliette',
#   'disse',
#   'q',
#   'vai',
#   'dormir',
#   'no',
#   'quarto',
#   'colorido',
#   'com',
#   'joão',
#   'bbb',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'juliette',
#   'sarah'],
#  ['rt',
#   'gil',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavraseuliette',
#   'globo…'],
#  ['bigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'juliette',
#   'e',
#   'sarah',
#   'falta',
#   'a',
#   'pocah',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'chorou',
#   'camilla',
#   'e',
#   'juliette',
#   'https//tco/8jssrj7cbl'],
#  ['juliette',
#   'hoje',
#   'suou',
#   'no',
#   'gerenciamento',
#   'de',
#   'crise',
#   'conversou',
#   'com',
#   'todo',
#   'o',
#   'mundo',
#   'para',
#   'desfazer',
#   'o',
#   'mau',
#   'entendido',
#   'bigbrotherbrasil',
#   'bbb21',
#   'bbb21aovivo'],
#  ['rt',
#   'cadê',
#   'o',
#   'com',
#   'plantão',
#   'dessa',
#   'treta',
#   'gente',
#   'foragilberto',
#   'foragil',
#   'gilette',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbra…'],
#  ['bbb21',
#   'gilberto',
#   'compara',
#   'homofobia',
#   'ao',
#   'olhar',
#   'de',
#   'juliette',
#   'freire',
#   'pro',
#   'fiuk',
#   'fumandoeuliette',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'freirejuliette',
#   'voltouhttps//tco/rfsgbepowj',
#   '-'],
#  ['mentiubigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'juliette',
#   'e',
#   'sarah',
#   'falta',
#   'a',
#   'pocah',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'calabocamajuhipocrita',
#   'viviane',
#   'tube',
#   'branqueline',
#   'sempre',
#   'https//tco/kb7yg1xxex'],
#  ['rt',
#   'pelo',
#   'amor',
#   'eu',
#   'tou',
#   'cansada',
#   'de',
#   'vcs',
#   'decidi',
#   'que',
#   'não',
#   'vou',
#   'torcer',
#   'pra',
#   'ninguém',
#   'nessa',
#   'porra',
#   'e',
#   'se',
#   'se',
#   'vcs',
#   'inventarem',
#   'de',
#   'tirar',
#   'os…'],
#  ['todo',
#   'mundo',
#   'fala',
#   'mal',
#   'de',
#   'todo',
#   'mundo',
#   'mas',
#   'ela',
#   'não',
#   'fala',
#   'mal',
#   'de',
#   'ninguém',
#   'ksksksksksksjuliette',
#   'hipócrita',
#   'da',
#   'silvabbb21',
#   'bigbrotherbrasil'],
#  ['bbb21',
#   'gilberto',
#   'compara',
#   'homofobia',
#   'ao',
#   'olhar',
#   'de',
#   'juliette',
#   'freire',
#   'pro',
#   'fiuk',
#   'fumandoeuliette',
#   'globolixo',
#   'o',
#   'choro',
#   'é',
#   'livre',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'https//tco/rfsgbepowj',
#   '-'],
#  ['gilberto',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavraseuliette',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'dia',
#   'do',
#   'fã',
#   'carla',
#   'diazhttps//tco/pomrql9dem'],
#  ['o',
#   'caio',
#   'parece',
#   'que',
#   'vai',
#   'explodir',
#   'de',
#   'tanta',
#   'força',
#   'no',
#   'gogó',
#   'pra',
#   'cantar',
#   'bbb21',
#   'festadolider',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['bbb21',
#   'gilberto',
#   'compara',
#   'homofobia',
#   'ao',
#   'olhar',
#   'de',
#   'juliette',
#   'freire',
#   'pro',
#   'fiuk',
#   'fumandoeuliette',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'freirejuliette',
#   'voltou',
#   'https//tco/rfsgbepowj'],
#  ['rt',
#   'arthur',
#   'deu',
#   'o',
#   'nome',
#   'do',
#   'cachorro',
#   'de',
#   'decoração',
#   'da',
#   'sala',
#   'de',
#   'projota',
#   'e',
#   'está',
#   'conversando',
#   'com',
#   'ele',
#   'até',
#   'o',
#   'cachorro',
#   'tem',
#   'mais',
#   'atenção…'],
#  ['gil',
#   'quem',
#   'quiser',
#   'ficar',
#   'nessa',
#   'casa',
#   'que',
#   'me',
#   'aguente',
#   'a',
#   'prova',
#   'de',
#   'resistência',
#   'aqui',
#   'dentro',
#   'dessa',
#   'casa',
#   'vai',
#   'ser',
#   'eu',
#   'me',
#   'aguentebbb21',
#   'bigbrotherbrasil',
#   'redebbb',
#   'big21',
#   'globoplay',
#   'foragil'],
#  ['gil',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavraseuliette',
#   'globolixo',
#   'o',
#   'choro',
#   'é',
#   'livre',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'https//tco/pomrql9dem',
#   '-'],
#  ['carla',
#   'diaz',
#   'diz',
#   'estar',
#   'envergonhada',
#   'e',
#   'juliette',
#   'brinca',
#   'uma',
#   'bebê',
#   'dessa',
#   'nunca',
#   'mais',
#   'no',
#   'quarto',
#   'colorido',
#   'após',
#   'a',
#   'festa',
#   'do',
#   'líder',
#   'fiuk',
#   'nhttps//tco/sabkrbwb26bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['juliette',
#   'arrasou',
#   'só',
#   'achobbb21',
#   'redebbb',
#   'catbbb',
#   'bigbrotherbrasil'],
#  ['arthur',
#   'dispara',
#   'para',
#   'carla',
#   'diaz',
#   'no',
#   'bbb21',
#   'o',
#   'brasil',
#   'está',
#   'vendo',
#   'está',
#   'me',
#   'julgand',
#   'carla',
#   'diaz',
#   'conversa',
#   'com',
#   'arthur',
#   'no',
#   'quarto',
#   'coloridohttps//tco/w0ryvzcy9cbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['rt',
#   'num',
#   'possível',
#   'paredão',
#   'quem',
#   'saibbb',
#   'bbb21',
#   'juliette',
#   'forasarah',
#   'foraarthur',
#   'foragil',
#   'teamjuliette',
#   'redebbb',
#   'bigbrother202…'],
#  ['juliette',
#   'é',
#   'a',
#   'pessoa',
#   'mais',
#   'egocentrica',
#   'da',
#   'casa',
#   'mas',
#   'vocês',
#   'não',
#   'estão',
#   'preparados',
#   'para',
#   'essa',
#   'conversa',
#   'todas',
#   'as',
#   'ações',
#   'dela',
#   'é',
#   'para',
#   'beneficio',
#   'próprio',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021'],
#  ['corre',
#   'para',
#   'conferir',
#   'o',
#   'meu',
#   'vídeo',
#   'da',
#   'setima',
#   'semana',
#   'do',
#   'bbb',
#   '21',
#   '😱🤩toda',
#   'quinta',
#   'tem',
#   'episódio',
#   'novo',
#   'no',
#   'canal',
#   'bbb2021',
#   'bbb21',
#   'bbb21',
#   'bbb2021',
#   'bigbrotherbrasil',
#   'bigbhotherbrasil',
#   'globo',
#   'gshow',
#   'gshow',
#   'redebbb21',
#   'redebbb',
#   'redebbb',
#   'globo',
#   'globoplay',
#   'globoplay',
#   'https//tco/lit5w2ociu'],
#  ['ana',
#   'maria',
#   'não',
#   'perdoa',
#   'mostra',
#   'vídeo',
#   'de',
#   'lucas',
#   'comemorando',
#   'eliminação',
#   'de',
#   'projota',
#   'que',
#   'fica',
#   'sem',
#   'graça',
#   'ao',
#   'vivo',
#   '-',
#   'https//tco/9qs9ezwmyr',
#   'bbb21',
#   'bbb',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'paredão',
#   'anamaria',
#   'maisvocê'],
#  ['pocah',
#   'sobre',
#   'jogo',
#   'de',
#   'alguns',
#   'brothers',
#   'do',
#   'bbb21',
#   'isso',
#   'me',
#   'assusta',
#   'pocah',
#   'sobre',
#   'jogo',
#   'de',
#   'alguns',
#   'brothers',
#   'do',
#   'bbb21',
#   'amp3https//tco/zufypavn7tbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['arthur',
#   'desabafa',
#   'com',
#   'pocah',
#   'eu',
#   'não',
#   'queria',
#   'ter',
#   'sentimentos',
#   'por',
#   'ela',
#   'pocah',
#   'chama',
#   'arthur',
#   'para',
#   'conversar',
#   'e',
#   'pergunta',
#   'parahttps//tco/tkmew5vtk1bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['num',
#   'possível',
#   'paredão',
#   'quem',
#   'saibbb',
#   'bbb21',
#   'juliette',
#   'forasarah',
#   'foraarthur',
#   'foragil',
#   'teamjuliette',
#   'redebbb',
#   'bigbrother2021',
#   'bigbrotherbrasil'],
#  ['tô',
#   'preocupada',
#   'com',
#   'essa',
#   'análise',
#   'da',
#   'camila',
#   'não',
#   'vejo',
#   'o',
#   'problema',
#   'que',
#   'ela',
#   'tá',
#   'vendo',
#   'por',
#   'que',
#   'será',
#   'que',
#   'tá',
#   'pilhada',
#   'desse',
#   'jeito',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['saudades',
#   'da',
#   'adolescência',
#   '🥺playlist',
#   'da',
#   'festa',
#   'do',
#   'líder',
#   'está',
#   'sensacional',
#   'bbb21',
#   'rock',
#   'festadolider',
#   'bigbrotherbrasil'],
#  ['gil',
#   'vc',
#   'é',
#   'falso',
#   'gilbbb21',
#   'bbb21',
#   'bigbrotherbrasil',
#   'foragil'],
#  ['mano',
#   'a',
#   'câmera',
#   'tava',
#   'fechada',
#   'no',
#   'arthur',
#   'e',
#   'na',
#   'hora',
#   'eu',
#   'pensei',
#   'que',
#   'ele',
#   'tava',
#   'cantando',
#   'sozinho',
#   'do',
#   'caetano',
#   'velozo',
#   'pra',
#   'carla',
#   'porque',
#   'ele',
#   'tava',
#   'todo',
#   'romântico',
#   'kkkkkkkkkk',
#   '🤡',
#   'era',
#   'pro',
#   'gil',
#   'bbb21',
#   'bbb21aovivo',
#   'bbb',
#   'bbb2021',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'festadofiuk',
#   'festadolider'],
#  ['bigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'agora',
#   'o',
#   'arthur',
#   'agora',
#   'a',
#   'carla',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'chorou',
#   'camilla',
#   'e',
#   'juliette',
#   'https//tco/8jssrj7cbl'],
#  ['quem',
#   'vai',
#   'ser',
#   'o',
#   'lider',
#   '👑',
#   'da',
#   'semana',
#   'enquete',
#   'globo',
#   'bbb',
#   'bbb2021',
#   'bbb',
#   'bbb',
#   'bigbrotherbrasil',
#   'tiagoleifert',
#   'multishow',
#   'programa',
#   'fiuk',
#   'sarah'],
#  ['gilberto',
#   'e',
#   'juliette',
#   'devem',
#   'ficar',
#   'até',
#   'o',
#   'final',
#   'junto',
#   'com',
#   'a',
#   'sarah',
#   'isso',
#   'depende',
#   'de',
#   'nós',
#   'o',
#   'estrago',
#   'que',
#   'a',
#   'lumens',
#   'fez',
#   'ao',
#   'entrar',
#   'na',
#   'cabeça',
#   'do',
#   'gil',
#   'foi',
#   'sério',
#   'demais',
#   'euliette',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'freirejuliette',
#   'voltou'],
#  ['juliette',
#   'tá',
#   'é',
#   'procurando',
#   'um',
#   'vetezinho',
#   'básico',
#   'de',
#   'vítima',
#   'sensata',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'anamaria'],
#  ['rt',
#   'louco',
#   'para',
#   'o',
#   'gilberto',
#   'dar',
#   'um',
#   'baile',
#   'na',
#   'viih',
#   'tube',
#   'garota',
#   'nojenta',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['resumo',
#   'bbb21',
#   '17/3',
#   'polêmica',
#   'no',
#   'queridômetro',
#   'treta',
#   'no',
#   'g3',
#   'e',
#   'cinema',
#   'do',
#   'líder',
#   'rep',
#   'gshow/bbbvote',
#   'também',
#   'na',
#   'enquete',
#   'bbbhttps//tco/3tuumn7j6pbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['arthur',
#   'chorando',
#   'de',
#   'saudade',
#   'do',
#   'projota',
#   'semana',
#   'que',
#   'vem',
#   'vcs',
#   'encontram',
#   'relaxa',
#   'bbb21',
#   'festadolider',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['muito',
#   'conveniente',
#   'agora',
#   'que',
#   'a',
#   'thais',
#   'voltou',
#   'do',
#   'paredão',
#   'o',
#   'fiuk',
#   'lembrar',
#   'que',
#   'ela',
#   'existe',
#   'a',
#   'bichinha',
#   'todo',
#   'feliz',
#   'odóbigbrotherbrasil',
#   'bigbrother',
#   'bbb21',
#   'bbb'],
#  ['ahhh',
#   'meu',
#   'pai',
#   'tem',
#   'uma',
#   'bateria',
#   'mil',
#   'vezes',
#   'melhor',
#   'que',
#   'essa',
#   'foda-se',
#   'vih',
#   'tubebbb',
#   'bigbrotherbrasil',
#   'bbb21',
#   'festadofiuk',
#   'festadolider'],
#  ['arthur',
#   'só',
#   'tem',
#   '2',
#   'camisas1',
#   'camisa',
#   'xadrez',
#   'vermelha',
#   'e',
#   '2',
#   'camisa',
#   'preta',
#   'de',
#   'flores',
#   'verdes',
#   'da',
#   'sera',
#   'q',
#   'ele',
#   'lava',
#   'e',
#   'usa',
#   'o',
#   'bom',
#   'q',
#   'a',
#   'mala',
#   'é',
#   'rápida',
#   'de',
#   'arrumar',
#   'e',
#   'ir',
#   'emborabbb21',
#   'redebbb',
#   'catbbb',
#   'bigbrotherbrasil'],
#  ['o',
#   'arthur',
#   'nem',
#   'olha',
#   'mais',
#   'nos',
#   'olhos',
#   'da',
#   'carlaredebbb',
#   'bbb21',
#   'bbb2021',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'bbb21carla',
#   'carladiaz'],
#  ['eu',
#   'acho',
#   'que',
#   'o',
#   'arthur',
#   'e',
#   'a',
#   'sarah',
#   'sei',
#   'não🔥🔥🔥🔥🔥🔥',
#   'se',
#   'a',
#   'carla',
#   'diaz',
#   'sair',
#   'do',
#   'programa😜teamsarah',
#   'teamgil',
#   'teamfiuk',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['rapaz',
#   'juliete',
#   'enterrou',
#   'o',
#   'gil',
#   'do',
#   'vigor',
#   'hoje',
#   'e',
#   'amanhã',
#   'faz',
#   'um',
#   'diafalou',
#   'que',
#   'se',
#   'fosse',
#   'conversar',
#   'com',
#   'argumentos',
#   'ela',
#   'conversava',
#   'e',
#   'taí',
#   'a',
#   'resposta',
#   'gil',
#   'nao',
#   'tem',
#   'argumento',
#   'nenhum',
#   'e',
#   'so',
#   'ouviu',
#   'daqui',
#   'a',
#   'pouco',
#   'vai',
#   'la',
#   'na',
#   'sarah',
#   'meter',
#   'o',
#   'pau',
#   'bbb21bbb2021',
#   'bigbrotherbrasil',
#   'https//tco/1a1mjvbo5w'],
#  ['se',
#   'declarando',
#   'pro',
#   'projota',
#   '🗣que',
#   'cena',
#   'ridicula',
#   '🤣🤣🤣redebbb',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['momento',
#   'bbb',
#   'fiuk',
#   'faz',
#   'boa',
#   'leitura',
#   'do',
#   'discurso',
#   'de',
#   'thiago',
#   'sobre',
#   'projota',
#   'foi',
#   'no',
#   'iníciobbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebnb',
#   'https//tco/paqspncdai'],
#  ['rt',
#   'arthur',
#   'só',
#   'tem',
#   '2',
#   'camisas1',
#   'camisa',
#   'xadrez',
#   'vermelha',
#   'e',
#   '2',
#   'camisa',
#   'preta',
#   'de',
#   'flores',
#   'verdes',
#   'da',
#   'sera',
#   'q',
#   'ele',
#   'lava…'],
#  ['me',
#   'quebrou',
#   'nesse',
#   'eu',
#   'gosto',
#   'de',
#   'tu',
#   'vey',
#   'ela',
#   'gosta',
#   'ele',
#   'quem',
#   'não',
#   'gosta',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'juliettecampea'],
#  ['projota',
#   'fala',
#   'sobre',
#   'dificuldade',
#   'para',
#   'comer',
#   'no',
#   '‘bbb21’',
#   '‘só',
#   'gosto',
#   'do',
#   'mais',
#   'snota',
#   'de',
#   'esclarecimento',
#   'a',
#   'três',
#   'comércihttps//tco/hal2x8lnxybbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['gil',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavraseuliette',
#   'globolixo',
#   'o',
#   'choro',
#   'é',
#   'livre',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'https//tco/pomrql9dem',
#   '/'],
#  ['gente',
#   'essa',
#   'festa',
#   'do',
#   'fiuk',
#   'flopou',
#   'mesmo',
#   'ou',
#   'é',
#   'impressão',
#   'minhabbb',
#   'bbb21',
#   'bbb2021',
#   'bigbrotherbrasil',
#   'bigbrotherbrasil21'],
#  ['como',
#   'deixar',
#   'uma',
#   'festa',
#   'extremamente',
#   'chatapasso',
#   '1',
#   'coloquei',
#   'músicas',
#   'do',
#   'fiukpasso',
#   '2',
#   'coloque',
#   'rockbbb21',
#   'bigbrotherbrasil'],
#  ['rt',
#   'hoje',
#   'é',
#   'dia',
#   'de',
#   'live',
#   'do',
#   'big',
#   'brother',
#   'brasil',
#   'a',
#   'partir',
#   'das',
#   '20h',
#   'estaremos',
#   'saboreando',
#   'um',
#   'bom',
#   'estrogonofe',
#   'em',
#   'homenagem',
#   'a',
#   'saída',
#   'de…'],
#  ['sarah',
#   'não',
#   'me',
#   'engana',
#   'ela',
#   'é',
#   'puro',
#   'veneno',
#   'a',
#   'cara',
#   'de',
#   'inveja',
#   'que',
#   'ela',
#   'olha',
#   'pra',
#   'ju',
#   'misericórdia',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['bbb21',
#   'sarah',
#   'se',
#   'diz',
#   'chateada',
#   'e',
#   'viih',
#   'tube',
#   'dispara',
#   'caguei',
#   'durante',
#   'conversa',
#   'na',
#   'noite',
#   'desta',
#   'terça-feirahttps//tco/tqcqw1hvsbbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['produção',
#   'jogando',
#   'baixo',
#   'que',
#   'feio',
#   'hein',
#   'os',
#   'maricas',
#   'dois',
#   'em',
#   'um',
#   'é',
#   'um',
#   'santo',
#   'do',
#   'pau',
#   'oco',
#   'a',
#   'falsiane',
#   'é',
#   'mocinha',
#   'a',
#   'trouxa',
#   'é',
#   'coitada',
#   'ah',
#   'me',
#   'poupem',
#   'vairedebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bbb'],
#  ['kakakakakakakakakakakakakakakchaveiro',
#   'de',
#   'camarote',
#   'bbb21',
#   'bigbrotherbrasil',
#   'https//tco/oxetulakje'],
#  ['traz',
#   'uns',
#   'boy',
#   'pra',
#   'casa',
#   'do',
#   'bbb',
#   'as',
#   'mulé',
#   'tão',
#   'tudo',
#   'carente',
#   'kkkkkkkkkk',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bbb',
#   'bbb20',
#   'https//tco/zrikxgjsl4'],
#  ['camila',
#   'é',
#   'minha',
#   'finalista',
#   'sensata',
#   'pra',
#   'um',
#   'caramba',
#   'bbb21',
#   'bigbrotherbrasil',
#   'festadolider'],
#  ['assista', 'bigbrotherbrasil', 'pelo', 'globoplay', 'https//tco/wbzfg6kfmn'],
#  ['a',
#   'galera',
#   'brigando',
#   'entre',
#   'gil',
#   'sarah',
#   'e',
#   'juliette',
#   'a',
#   'final',
#   'vai',
#   'ser',
#   'pocah',
#   'thais',
#   'e',
#   'viih',
#   'tirem',
#   'os',
#   'que',
#   'movimentam',
#   'o',
#   'jogo',
#   'pra',
#   've',
#   'se',
#   'vão',
#   'conseguir',
#   'assistir',
#   'insuportável',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['quem',
#   'vai',
#   'ser',
#   'o',
#   'lider',
#   '👑',
#   'da',
#   'semana',
#   'enquete',
#   'globo',
#   'bbb',
#   'bbb2021',
#   'bbb',
#   'bbb',
#   'bigbrotherbrasil',
#   'tiagoleifert',
#   'multishow',
#   'programa',
#   'joaoluiz',
#   'viihtube',
#   'juliette'],
#  ['rt',
#   'ao',
#   'você',
#   'liga',
#   'seu',
#   'ppv',
#   'e',
#   'dá',
#   'de',
#   'cara',
#   'com',
#   'a',
#   'dormindo',
#   'e',
#   'vc',
#   'pensa',
#   'é',
#   'exatamente',
#   'pra',
#   'isso',
#   'que',
#   'eu',
#   'pago',
#   'ppv',
#   'hahahahahahhaa',
#   '…'],
#  ['ahahaha',
#   'a',
#   'camila',
#   'e',
#   'o',
#   'joãobbb21',
#   'festadolider',
#   'bigbrotherbrasil',
#   'https//tco/noqlno5iec'],
#  ['que',
#   'aula',
#   'de',
#   'visão',
#   'e',
#   'conhecimento',
#   'das',
#   'próprias',
#   'dores',
#   'das',
#   'dores',
#   'dos',
#   'outros',
#   'e',
#   'de',
#   'como',
#   'ganhar',
#   'sem',
#   'passar',
#   'por',
#   'cima',
#   'de',
#   'ninguém',
#   'é',
#   'esse',
#   'o',
#   'jogo',
#   'que',
#   'as',
#   'pessoas',
#   'querem',
#   'ver',
#   'teamjuliette',
#   'bigbrotherbrasil',
#   'juliettefreire',
#   'juliettecampeã',
#   'bbb21'],
#  ['encomenda',
#   'do',
#   'dia',
#   '💯bbb21',
#   'bbb',
#   'redebbb',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'collage',
#   'artwork',
#   'carladiaz',
#   'carlanoquartosecreto',
#   'artwork',
#   'bbb2021',
#   'redebbbb',
#   'art',
#   'collage',
#   'https//tco/1bhtbgirwt'],
#  ['vai',
#   'a',
#   'merda',
#   'carla',
#   'vc',
#   'cogitou',
#   'votar',
#   'ate',
#   'na',
#   'julliete',
#   'pra',
#   'salva',
#   'seu',
#   'banana',
#   'bbb21',
#   'bigbrotherbrasil',
#   'teamgil',
#   'teamjuliette',
#   'teamsarah'],
#  ['meu',
#   'deus',
#   'que',
#   'bizarro',
#   '😂😂crossfiteiro',
#   'de',
#   'merda',
#   'bbb21',
#   'redebbb',
#   'bbb',
#   'bigbrotherbrasil',
#   'https//tco/qfubhkfrih'],
#  ['a',
#   'diferença',
#   'da',
#   'culpa',
#   'é',
#   'uma',
#   'ta',
#   'conversando',
#   'sobre',
#   'peido',
#   'e',
#   'rindo',
#   'o',
#   'outro',
#   'chorando',
#   'horrores',
#   'sozinho',
#   '🤷🏽\u200d♀️',
#   'bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['a',
#   'vida',
#   'da',
#   'protagonista',
#   'ta',
#   'difícilai',
#   'carla',
#   'vai',
#   'tomar',
#   'no',
#   'seu',
#   'uc',
#   'não',
#   'vejo',
#   'a',
#   'hora',
#   'de',
#   'te',
#   'vee',
#   'fora',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['meu',
#   'deus',
#   'que',
#   'ridículo',
#   'isso',
#   'pqp',
#   '🙄🙄redebbb',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['g3',
#   'era',
#   'muito',
#   'perfeito',
#   'pra',
#   'ser',
#   'verdade',
#   '🤧🤧🤧🤧',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['e',
#   'o',
#   'fiuk',
#   'visivelmente',
#   'não',
#   'curte',
#   'ninguém',
#   'ninguém',
#   'ninguém',
#   'mesmo',
#   'escuta',
#   'alive',
#   'e',
#   'fica',
#   'calado',
#   'festadofiuk',
#   'bigbrotherbrasil'],
#  ['—',
#   'o',
#   'seu',
#   'amor',
#   'pra',
#   'mim',
#   'é',
#   'tudo',
#   '❤',
#   '•••••••••',
#   'bilaraujo',
#   'bbb',
#   'bbb21',
#   'teambil',
#   'arcrebiano',
#   'teamjuliette',
#   'globo',
#   'tvglobo',
#   'bigbrother',
#   'bigbrotherbrasil',
#   'https//tco/41texrl92e'],
#  ['aewwwww',
#   'os',
#   'cactos',
#   'vitimistas',
#   'estão',
#   'felizes',
#   'novamenteredebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'paredaobbb',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea',
#   'https//tco/ztj3zqwua6',
#   'https//tco/ztj3zqwua6'],
#  ['mártir',
#   'julietelá',
#   'ninguém',
#   'é',
#   'bobinho',
#   'que',
#   'não',
#   'saiba',
#   'se',
#   'defender',
#   'acho',
#   'que',
#   'faz',
#   'parte',
#   'da',
#   'estratégia',
#   'dela',
#   'quem',
#   'tem',
#   'informação',
#   'tem',
#   'poder',
#   'ela',
#   'quer',
# ...
#   'redebbb',
#   'festadolider'],
#  ['nossa',
#   'tinha',
#   'tantas',
#   'coisas',
#   'legais',
#   'para',
#   'fazer',
#   'de',
#   'tema',
#   'na',
#   'festa',
#   'do',
#   'fiuk',
#   'e',
#   'eles',
#   'me',
#   'entregam',
#   'isso',
#   '🤡🤡',
#   'que',
#   'm',
#   'achei',
#   'fraquinho',
#   'demais',
#   'essa',
#   'decô',
#   'bbb21',
#   'bigbrotherbrasil',
#   'fiuk',
#   'https//tco/woao0pjhyn'],
#  ['tag',
#   'de',
#   'hoje',
#   'twitter',
#   'libera',
#   'juliettebanida',
#   'injustamentebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'https//tco/s5xr8ostuq'],
#  ['assino',
#   'embaixo',
#   'oportunistas',
#   'do',
#   'caraio',
#   'bbb21',
#   'bigbrotherbrasil',
#   'forajuliette',
#   'https//tco/fbqm7ypdbv'],
#  ['isso',
#   'mostra',
#   'q',
#   'ele',
#   'confiou',
#   'falsidade',
#   'a',
#   'pessoas',
#   'erradas',
#   'lamentável',
#   'bbb',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['aaaaaaaa',
#   'que',
#   'legal',
#   'vi',
#   'não',
#   'está',
#   'com',
#   'carla',
#   'por',
#   'medo',
#   'né',
#   'kkkkkkk',
#   'tá',
#   'pq',
#   'está',
#   'arrependida',
#   'kkkkkkkkkkkkkkkk',
#   'o',
#   'pior',
#   'é',
#   'juliette',
#   'falar',
#   'que',
#   'sabe',
#   'kkkkkkkkk',
#   'meu',
#   'deus',
#   'esse',
#   'povo',
#   'fala',
#   'merda',
#   'em',
#   'cima',
#   'de',
#   'merdaassista',
#   'bigbrotherbrasil',
#   'pelo',
#   'globoplay',
#   'https//tco/bufy9d3h9x'],
#  ['e',
#   'hoje',
#   'é',
#   'a',
#   'festa',
#   'do',
#   'amor',
#   'da',
#   'minha',
#   'vidaaaaa',
#   'carinho',
#   'de',
#   'filho',
#   'viu',
#   'gente',
#   'kkkkbbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'https//tco/m4g2yjbeom'],
#  ['camila',
#   'assistindo',
#   'de',
#   'terror',
#   'filme',
#   'no',
#   'bbb',
#   'me',
#   'lembrou',
#   'a',
#   'brenda',
#   'no',
#   'cinema',
#   'de',
#   'todo',
#   'mundo',
#   'em',
#   'panico',
#   'bigbrother',
#   'bigbrotherbrasil',
#   'bbb21',
#   'https//tco/ekk4muwnuy'],
#  ['tô',
#   'quase',
#   'levantando',
#   'e',
#   'indo',
#   'dançar',
#   'com',
#   'essas',
#   'músicas',
#   'festadolider',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebbb21'],
#  ['gil',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavraseuliette',
#   'globolixo',
#   'o',
#   'choro',
#   'é',
#   'livre',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'https//tco/pomrql9dem'],
#  ['a',
#   'conversa',
#   'entre',
#   'sara',
#   'e',
#   'juliete',
#   'foi',
#   'cortada',
#   'na',
#   'edição',
#   'tipo',
#   'pra',
#   'mudar',
#   'o',
#   'sentido',
#   'redebbb',
#   'bbb',
#   'bigbrotherbrasil',
#   'big21'],
#  ['porra',
#   'achei',
#   'q',
#   'a',
#   'festa',
#   'era',
#   'vef3',
#   'desafio',
#   'em',
#   'tóquiochatão',
#   'isso',
#   'ai',
#   'einredebbb',
#   'redebbb21',
#   'bigbrotherbrasil'],
#  ['esse',
#   'bbb',
#   'tá',
#   'parecendo',
#   'jogos',
#   'vorazes',
#   'todo',
#   'mundo',
#   'se',
#   'matando',
#   'ihul',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil'],
#  ['thais',
#   'foi',
#   'pro',
#   'confessionário',
#   'tomar',
#   'glicose',
#   'eitchaaaa',
#   'festadolider',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['carla',
#   'diaz',
#   'sobre',
#   'brother',
#   'do',
#   'bbb21',
#   'ele',
#   'está',
#   'desesperado',
#   'carla',
#   'diaz',
#   'sobre',
#   'brother',
#   'do',
#   'bbb21',
#   'ele',
#   'estáhttps//tco/tuiiduo1tbbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['assista',
#   'bigbrotherbrasil',
#   'pelo',
#   'globoplay',
#   'https//tco/ajr5ae8cwn',
#   'direto',
#   'do',
#   'túnel',
#   'do',
#   'tempo^^',
#   'redebbb',
#   'bbb21'],
#  ['de',
#   'qual',
#   'lado',
#   'vocês',
#   'estão',
#   'juliette',
#   'curti',
#   'gil',
#   'comenta',
#   'teamjuliette',
#   'bbb2021',
#   'redebbb',
#   'gilbbb21',
#   'juliettecampea',
#   'bigbrotherbrasil',
#   'https//tco/mjd2zkqadu'],
#  ['quem',
#   'você',
#   'eliminariaforagil',
#   'forasarah',
#   'foraviihtube',
#   'bigbrotherbrasil'],
#  ['sarah',
#   'conta',
#   'não',
#   'ter',
#   'dado',
#   'coração',
#   'para',
#   'sisters',
#   'do',
#   'bbb21',
#   'e',
#   'diz',
#   'se',
#   'perguntarem',
#   'sarah',
#   'conta',
#   'não',
#   'ter',
#   'dado',
#   'coração',
#   'para',
#   'sisters',
#   'https//tco/n1jigvldgtbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['até',
#   'que',
#   'enfim',
#   'música',
#   'decente',
#   'nessa',
#   'festa',
#   'do',
#   'líder',
#   'teamsarah',
#   'teamgil',
#   'teamfiuk',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021'],
#  ['nessa',
#   'paredao',
#   'quem',
#   'vocês',
#   'eliminariam',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'festabbb'],
#  ['conseguimosagora',
#   'o',
#   'alvo',
#   'é',
#   'o',
#   'bananãobbb21bbb',
#   'bigbrotherbrasil',
#   'bigbrothertchau',
#   'projota',
#   'agora',
#   'a',
#   'carla',
#   'caralho',
#   '91',
#   'ate',
#   'o',
#   'fiuk',
#   'calma',
#   'arthur',
#   'ana',
#   'maria',
#   'tiago',
#   'globo',
#   'https//tco/ffwyaosgqo'],
#  ['depois',
#   'de',
#   'ver',
#   'o',
#   'caio',
#   'expondo',
#   'gil',
#   'e',
#   'sarah',
#   'para',
#   'carla',
#   'chego',
#   'a',
#   'conclusão',
#   'que',
#   'ele',
#   'consegue',
#   'ser',
#   'mais',
#   'falso',
#   'que',
#   'a',
#   'vih',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['diegobigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'agora',
#   'o',
#   'arthur',
#   'agora',
#   'a',
#   'carla',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'chorou',
#   'camilla',
#   'e',
#   'juliette',
#   'https//tco/kb7yg1xxex'],
#  ['esse',
#   'foi',
#   'o',
#   'dia',
#   'em',
#   'que',
#   'ela',
#   'falou',
#   'com',
#   'sarah',
#   'da',
#   'atitude',
#   'de',
#   'lumena',
#   'com',
#   'público',
#   'assista',
#   'bigbrotherbrasil',
#   'pelo',
#   'globoplay',
#   'https//tco/gzr3lycp68'],
#  ['o',
#   'tema',
#   'do',
#   'bbb20',
#   'foi',
#   'machismo',
#   'o',
#   'dessa',
#   'edição',
#   'tá',
#   'sendo',
#   'fofoca',
#   'bbb21',
#   'bbb',
#   'bigbrotherbrasil'],
#  ['gente',
#   'alguém',
#   'me',
#   'avisa',
#   'quando',
#   'o',
#   'arthur',
#   'começar',
#   'a',
#   'tocar',
#   'o',
#   'terror',
#   'na',
#   'festa',
#   'por',
#   'gentileza',
#   'bbb21',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['o',
#   'jogo',
#   'dela',
#   'virou',
#   'totalmente',
#   'depois',
#   'da',
#   'volta',
#   'da',
#   'carla',
#   'e',
#   'de',
#   'suas',
#   'informações',
#   'distorcidas',
#   'gil',
#   'e',
#   'sarah',
#   'estão',
#   'errados',
#   'não',
#   'acho',
#   'bbb21',
#   'bigbrotherbrasil',
#   'foracarla',
#   'foravihtube'],
#  ['por',
#   'mim',
#   'o',
#   'bbb21',
#   'pode',
#   'terminar',
#   'hoje',
#   'com',
#   'julietexampeãbigbrotherbrasil',
#   'bigbrother2021rançodogil'],
#  ['rt',
#   'eu',
#   'to',
#   'berrando👉🏻',
#   'siga',
#   'para',
#   'notícias',
#   'do',
#   'bbb21🎥',
#   'créditos/reprodução',
#   'bbb',
#   '/',
#   'globoplay',
#   '/',
#   'gshow',
#   '/',
#   'rede',
#   'globo…'],
#  ['eu',
#   'to',
#   'berrando👉🏻',
#   'siga',
#   'para',
#   'notícias',
#   'do',
#   'bbb21🎥',
#   'créditos/reprodução',
#   'bbb',
#   '/',
#   'globoplay',
#   '/',
#   'gshow',
#   '/',
#   'rede',
#   'globorealityshow',
#   'famosos',
#   'bbb',
#   'tretas',
#   'pocah',
#   'celebridades',
#   'fofocas',
#   'humor',
#   'memes',
#   'tiktokbrasil',
#   'bigbrotherbrasil',
#   'tiktok',
#   'redebbb',
#   'projota',
#   'https//tco/7jz3byfxce'],
#  ['assista', 'bigbrotherbrasil', 'pelo', 'globoplay', 'https//tco/fifnatmaai'],
#  ['juliete', 'tá', 'um', 'saco', 'embbb21', 'bigbrotherbrasil'],
#  ['hoje',
#   'festa',
#   'do',
#   'bbb',
#   'vai',
#   'dar',
#   'merda',
#   'ficam',
#   'vendo',
#   '😂😂😂',
#   'bigbrotherbrasil',
#   'bbb21',
#   'festabbb21'],
#  ['como',
#   'faz',
#   'pra',
#   'ser',
#   'amiga',
#   'da',
#   'juliettefreire',
#   'preciso',
#   'de',
#   'alguém',
#   'assim',
#   'na',
#   'minha',
#   'vidabbb21',
#   'paredaobbb',
#   'maisvoce',
#   'bigbrotherbrasil',
#   'https//tco/obfig6i1fk'],
#  ['fiuk',
#   'acorda',
#   'brothers',
#   'depois',
#   'de',
#   'receber',
#   'comes',
#   'e',
#   'bebes',
#   'no',
#   'bbb21',
#   'enquanto',
#   'boa',
#   'parte',
#   'dos',
#   'brothers',
#   'dorme',
#   'na',
#   'casa',
#   'do',
#   'https//tco/ertejtaxyubbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['olha',
#   'só',
#   'to',
#   'gostando',
#   'do',
#   'show',
#   'do',
#   'fiuk',
#   'seu',
#   'irmão',
#   'é',
#   'maneiro',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'queria',
#   'ser',
#   'cunhado',
#   'dele',
#   '😜'],
#  ['amémbigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'juliette',
#   'e',
#   'sarah',
#   'falta',
#   'a',
#   'pocah',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'calabocamajuhipocrita',
#   'viviane',
#   'tube',
#   'branqueline',
#   'sempre',
#   'https//tco/8jssrj7cbl'],
#  ['voce',
#   'ta',
#   'em',
#   'qual',
#   'finalbbb21',
#   'bigbrotherbrasil',
#   'bbbb21',
#   'se',
#   'o',
#   'arthur',
#   'agora',
#   'o',
#   'arthur',
#   'agora',
#   'a',
#   'carla',
#   'bigbrother2021',
#   'o',
#   'vt',
#   'chorou',
#   'camilla',
#   'e',
#   'juliette',
#   'caio',
#   'e',
#   'rodolfo'],
#  ['quem',
#   'chegou',
#   'com',
#   'o',
#   'dedo',
#   'na',
#   'cara',
#   'de',
#   'quem',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'quartosecreto',
#   'avontaon',
#   'carladiaz',
#   'boninho',
#   'cancelaocardboninhosearanobbb21',
#   'https//tco/vknvr5yjzt'],
#  ['camilla',
#   'de',
#   'lucas',
#   'diz',
#   'para',
#   'arthur',
#   'ser',
#   'honesto',
#   'sobre',
#   'relação',
#   'com',
#   'carla',
#   'diaz',
#   'ac',
#   'após',
#   'ouvir',
#   'pocah',
#   'sobre',
#   'o',
#   'assunto',
#   'arthur',
#   'fala',
#   'cohttps//tco/4muxabtqagbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['arthur',
#   'vai',
#   'sentir',
#   'muita',
#   'saudade',
#   'do',
#   'projota',
#   'bbb21',
#   'bigbrotherbrasil',
#   'https//tco/r6wb2nvr1r'],
#  ['de',
#   'que',
#   'lado',
#   'vcs',
#   'estãobbb21',
#   'redebbb',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021',
#   'festadolider'],
#  ['a',
#   'calça',
#   'da',
#   'jukiette',
#   'socorooooooo',
#   'que',
#   'coisa',
#   'mais',
#   'lindaaaaa',
#   'bbb21',
#   'bigbrotherbrasil'],
#  ['ai',
#   'queria',
#   'ficar',
#   'aqui',
#   'tweetando',
#   'sobre',
#   'a',
#   'festa',
#   'mas',
#   'as',
#   'músicas',
#   'tão',
#   'boa',
#   'tô',
#   'só',
#   'cantando',
#   'mas',
#   'queria',
#   'falar',
#   'que',
#   'o',
#   'gil',
#   'e',
#   'a',
#   'juliette',
#   'tão',
#   'se',
#   'declarando',
#   'pelas',
#   'letras',
#   'e',
#   'dançando',
#   'juntos',
#   'bbb21',
#   'festadolider',
#   'bigbrotherbrasil',
#   'redebbb21'],
#  ['no',
#   'quarto',
#   'colorido',
#   'pocah',
#   'desabafa',
#   'com',
#   'sister',
#   'eu',
#   'sentia',
#   'que',
#   'não',
#   'estava',
#   'conseg',
#   'no',
#   'quarto',
#   'colorido',
#   'pocah',
#   'desabafa',
#   'com',
#   'sister',
#   'amphttps//tco/y002ot8tdrbbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['olha',
#   'o',
#   'joão',
#   'jogando',
#   'a',
#   'semente',
#   'na',
#   'cabeça',
#   'da',
#   'sarah',
#   'kkkkkk',
#   'professor',
#   'planta',
#   'é',
#   'venenosobbb21',
#   'bigbrotherbrasil'],
#  ['juliette',
#   'brinca',
#   'antes',
#   'de',
#   'festa',
#   'do',
#   'líder',
#   'do',
#   'bbb21',
#   'fiuk',
#   'mandou',
#   'avisar',
#   'que',
#   'hoje',
#   'os',
#   'brothers',
#   'do',
#   'bbb21',
#   'estão',
#   'animados',
#   'para',
#   'a',
#   'festahttps//tco/l2f2gkuqvubbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['rt',
#   'gil',
#   'distorcendo',
#   'tds',
#   'as',
#   'palavras',
#   'e',
#   'ações',
#   'de',
#   'juliette',
#   'socorro',
#   'ele',
#   'precisa',
#   'ir',
#   'embora',
#   'o',
#   'cara',
#   'está',
#   'pirando',
#   'bbb21',
#   'redebb…'],
#  ['ainda',
#   'sobre',
#   'o',
#   'bbb21redebbb',
#   'bigbrotherbrasil',
#   'https//tco/3zotllt2a8'],
#  ['bbb',
#   'bigbrotherbrasil',
#   'gshow',
#   'bbb21',
#   'quero',
#   'ver',
#   'se',
#   'a',
#   'edição',
#   'do',
#   'programa',
#   'vai',
#   'continuar',
#   'mostrando',
#   'tudo',
#   'o',
#   'que',
#   'a',
#   'juliette',
#   'fala',
#   'e',
#   'como',
#   'fala',
#   'com',
#   'o',
#   'gil',
#   'e',
#   'umilha',
#   'ele',
#   'mais',
#   'espero',
#   'que',
#   'a',
#   'bagaceira',
#   'e',
#   'o',
#   'pau',
#   'tore',
#   'e',
#   'que',
#   'o',
#   'mostre',
#   'a',
#   'verdade',
#   'toda',
#   'eita',
#   '🔥🔥'],
#  ['esse', 'caio', 'é', 'uma', 'cobra', 'bbb', 'bbb21', 'bigbrotherbrasil'],
#  ['rt',
#   'excelente',
#   'jogadora',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'https//tco/k2cvlaba0z'],
#  ['📌karol',
#   'conká',
#   '-ain',
#   'vc',
#   'não',
#   'apoia',
#   'a',
#   'outra',
#   'preta📌camilla',
#   '-não',
#   'vem',
#   'misturar',
#   'falta',
#   'de',
#   'afinidade',
#   'com',
#   'militância',
#   'não',
#   'pq',
#   'não',
#   'sou',
#   'obrigada',
#   'a',
#   'gostar',
#   'de',
#   'vc',
#   'só',
#   'pq',
#   'vc',
#   'é',
#   'pretacamilla',
#   'de',
#   'lucas',
#   '2021camilla',
#   'jantou',
#   'cedo',
#   'hj😎bbb21',
#   'bbb',
#   'camiladelucas',
#   'karolconka',
#   'bigbrotherbrasil'],
#  ['juliette',
#   'está',
#   'falando',
#   'alto',
#   'e',
#   'pedindo',
#   'para',
#   'o',
#   'gil',
#   'falar',
#   'baixo',
#   'bbb21',
#   'bigbrotherbrasil',
#   'bigbrother2021'],
#  ['esse',
#   'vídeo',
#   'não',
#   'pode',
#   'morrer',
#   'kkkkkkkkkkkk',
#   'ela',
#   'é',
#   'difícil',
#   'demais',
#   'o',
#   'pessoal',
#   'não',
#   'fala',
#   'de',
#   'uma',
#   'pessoa',
#   'atoa',
#   'ficar',
#   'vivendo',
#   'o',
#   'bbb',
#   'só',
#   'como',
#   'espectador',
#   'não',
#   'é',
#   'legal',
#   'tem',
#   'que',
#   'pensar',
#   'com',
#   'a',
#   'cabeça',
#   'deles',
#   'lá',
#   'de',
#   'dentro',
#   'as',
#   'vezes',
#   'a',
#   'visão',
#   'deles',
#   'é',
#   'bem',
#   'limitadabbb21',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'https//tco/zfwr8hjfjh'],
#  ['eitha',
#   'que',
#   'juliette',
#   'jogando',
#   'tudo',
#   'na',
#   'cara',
#   'de',
#   'gil',
#   'vamos',
#   'ver',
#   'se',
#   'dessa',
#   'vez',
#   'ele',
#   'acorda',
#   'bigbrotherbrasil',
#   'gilbbb21',
#   'juliette'],
#  ['gil',
#   'já',
#   'traiu',
#   'muito',
#   'a',
#   'juliette',
#   'pelas',
#   'costas',
#   'não',
#   'adianta',
#   'chorar',
#   'amigo',
#   'de',
#   'verdade',
#   'não',
#   'faz',
#   'o',
#   'que',
#   'ele',
#   'fez',
#   'bbb',
#   'bigbrother2021',
#   'bigbrotherbrasil',
#   'bbb21',
#   'bbb2021'],
#  ['resumo',
#   'bbb21',
#   '18/03',
#   'festa',
#   'do',
#   'líder',
#   'fiuk',
#   'é',
#   'marcada',
#   'por',
#   'cantoria',
#   'dr',
#   'de',
#   'carla',
#   'direp',
#   'gshow/bbbvote',
#   'também',
#   'na',
#   'enquete',
#   'bbbhttps//tco/vdeqwjviv8bbb',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'afazenda',
#   'afazenda12',
#   'roçaafazenda',
#   'eliminaçãoafazenda'],
#  ['rt',
#   'bbb21',
#   'juliette',
#   'gilbbb21juliettebbb21',
#   'bigbrotherbrasilbigbrother2021',
#   'muita',
#   'tretaaaa',
#   'entre',
#   'gil',
#   'e',
#   'juliette',
#   'e…'],
#  ['podia',
#   'ter',
#   'fábio',
#   'júnior',
#   'cantando',
#   'ai',
#   'pra',
#   'dar',
#   'uma',
#   'animada',
#   'nessa',
#   'festabbb21',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['gilberto',
#   'e',
#   'juliette',
#   'travam',
#   'batalha',
#   'e',
#   'fãs',
#   'do',
#   'antigo',
#   'g3',
#   'se',
#   'dividem',
#   'juliette',
#   'é',
#   'massacrada',
#   'e',
#   'gil',
#   'fica',
#   'sem',
#   'palavras//euliette',
#   'viviane',
#   'tube',
#   'forajuliette',
#   'foragil',
#   'sempre',
#   'kerline',
#   'ju',
#   'e',
#   'gil',
#   'redebbb',
#   'bbb',
#   'bbb21',
#   'redebbb21',
#   'bigbrotherbrasil',
#   'freirejuliette',
#   'voltou',
#   'https//tco/pomrql9dem'],
#  ['rt',
#   'assim',
#   'de',
#   'saúde',
#   '🥺\U0001faa6🍒sarolffo',
#   'bbb21',
#   'bigbrother2021',
#   'bbb',
#   'bigbrotherbrasil',
#   'bigbrother',
#   'sarolfo',
#   'https//tco/uzijpsxpwl'],
#  ['estou',
#   'ignorando',
#   'todos',
#   'os',
#   'meus',
#   'compromissos',
#   'de',
#   'amanhã',
#   'e',
#   'estou',
#   'aqui',
#   'vendo',
#   'a',
#   'festa',
#   'do',
#   'bbb',
#   'e',
#   'ainda',
#   'postando',
#   'tweet',
#   'aí',
#   'jesus',
#   'festadolider',
#   'bbb21',
#   'bigbrotherbrasil',
#   'redebbb'],
#  ['de',
#   'qual',
#   'lado',
#   'você',
#   'está',
#   'juliettefreire',
#   'juliettecampea',
#   'bbb21',
#   'redebbb',
#   'bigbrotherbrasil',
#   'foragil'],
#  ['avisei',
#   'vcs',
#   'sarah',
#   'não',
#   'ia',
#   'acreditar',
#   'na',
#   'juliette',
#   'mais',
#   'uma',
#   'vez',
#   'redebbb',
#   'bbb21',
#   'bigbrotherbrasil',
#   'paredaobbb',
#   'festabbb',
#   'foraprojota',
#   'forapocah',
#   'foraarthur',
#   'forasarah',
#   'foragil',
#   'forafiuk',
#   'xepa',
#   'vip',
#   'juliettecampea']]

# %%
resultados = []
for frase in test['Teste']:
    classificacao = classifica_frase(frase)
    resultados.append(classificacao)
test['Resolução'] = resultados
test['Resolução']
# Out:
# 0        Outros BBB
# 1      Irrelevantes
# 2      Irrelevantes
# 3      Irrelevantes
# 4      Irrelevantes
#            ...
# 294      Outros BBB
# 295      Outros BBB
# 296      Outros BBB
# 297      Outros BBB
# 298      Outros BBB
# Name: Resolução, Length: 299, dtype: object

# %%
teste_BBB21 = test['BBB 21']
teste_Outros = test['Outros BBB']
teste_irrel = test['irrelevantes']

verdadeiro21 = 0
falso21 = 0
verdadeiroOutros = 0
falsoOutros = 0
verdadeiroIrrel = 0
falsoIrrel = 0

for i in range(len(resultados)):
    if resultados[i] == 'BBB21' and teste_BBB21[i] == 'x':
        verdadeiro21 += 1
    elif resultados [i] == 'BBB21' and teste_BBB21[i] != 'x':
        falso21 += 1
    if resultados[i] == 'Outros BBB' and teste_Outros[i] == 'x':
        verdadeiroOutros += 1
    elif resultados [i] == 'Outros BBB' and teste_Outros[i] != 'x':
        falsoOutros += 1
    if resultados[i] == 'Irrelevantes' and teste_irrel[i] == 'x':
        verdadeiroIrrel += 1
    elif resultados [i] == 'Irrelevantes' and teste_irrel[i] != 'x':
        falsoIrrel += 1
        
teste_BBB21_x = 0
teste_Outros_x = 0
teste_irrel_x = 0

for i in range(len(resultados)):
    if teste_BBB21[i] == 'x':
        teste_BBB21_x += 1
    elif teste_Outros[i] == 'x':
        teste_Outros_x += 1
    elif teste_irrel[i] == 'x':
        teste_irrel_x += 1 

verdadeiro21_porcentagem = (verdadeiro21/teste_BBB21_x)*100
falso21_porcentagem = (falso21/teste_BBB21_x)*100
verdadeiroOutros_porcentagem = (verdadeiroOutros/teste_Outros_x)*100
falsoOutros_porcentagem = (falsoOutros/teste_Outros_x)*100
verdadeiroIrrel_porcentagem = (verdadeiroIrrel/teste_irrel_x)*100
falsoIrrel_porcentagem = (falsoIrrel/teste_irrel_x)*100

print(f'Verdadeiros BBB 21: {verdadeiro21_porcentagem:.3f}% e Falsos BBB 21: {falso21_porcentagem:.3f}%\nVerdadeiros Outros BBB: {verdadeiroOutros_porcentagem:.3f}% e Falsos Outros BBB: {falsoOutros_porcentagem:.3f}%\nVerdadeiros irrelevantes: {verdadeiroIrrel_porcentagem:.3f}% e Falsos irrelevantes: {falsoIrrel_porcentagem:.3f}%')
total_de_acertos = verdadeiro21+verdadeiroOutros+verdadeiroIrrel
porcentagem_total = total_de_acertos/len(resultados)*100
print(f'Porcentagem geral de acertos: {porcentagem_total:.3f}%')
# Out:
# Verdadeiros BBB 21: 0.373% e Falsos BBB 21: 0.000%
# Verdadeiros Outros BBB: 66.667% e Falsos Outros BBB: 4300.000%
# Verdadeiros irrelevantes: 45.833% e Falsos irrelevantes: 104.167%
# Porcentagem geral de acertos: 5.351%

# %%
filtroBBB21 = test['Resolução'] == 'BBB 21'
filtro_outros = test['Resolução'] == 'Outros BBB'
filtro_ir = test['Resolução'] == 'Irrelevante'
#resoluçãoBBB21 = test['Teste'].loc[filtroBBB21,:]
filtro_outros = []
pd.crosstab([test['BBB 21'],test['Outros BBB'],test['irrelevantes']],[test['Resolução']],normalize='index')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
test
# Out:
#                                                  Teste BBB 21 Outros BBB  \
# 0    flans corre aqui   a quixitagem ta fofona dema...    NaN          x
# 1    sim bbtvi2020 followtrick follotrick kpop kpop...    NaN        NaN
# 2    so conheço o 1 e 3 ent nao posso opinarfollotr...    NaN        NaN
# 3    vou fazer meu msd de uma vezfollotrick bbtvi r...    NaN        NaN
# 4    legal as minhas favs 😍mas acho que vou de anyf...      x        NaN
# ..                                                 ...    ...        ...
# 294  gilberto e juliette travam batalha e fãs do an...      x        NaN
# 295  rt  assim de saúde 🥺🪦🍒sarolffo bbb21 bigbrothe...      x        NaN
# 296  estou ignorando todos os meus compromissos de ...      x        NaN
# 297  de qual lado você está juliettefreire juliette...      x        NaN
# 298  avisei vcs sarah não ia acreditar na juliette ...      x        NaN
#
#     irrelevantes     Resolução
# 0            NaN    Outros BBB
# 1              x  Irrelevantes
# 2              x  Irrelevantes
# 3              x  Irrelevantes
# 4            NaN  Irrelevantes
# ..           ...           ...
# 294          NaN    Outros BBB
# 295          NaN    Outros BBB
# 296          NaN    Outros BBB
# 297          NaN    Outros BBB
# 298          NaN    Outros BBB
#
# [299 rows x 5 columns]

# %%
resBBB21 = test.loc[filtroBBB21,:]
resBBB21
# Out:
# Empty DataFrame
# Columns: [Teste, BBB 21, Outros BBB, irrelevantes, Resolução]
# Index: []

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# O nosso classificador tem uma precisão de acertos de 5,351%. Para justificar, uma coisa que pode ter impactado tanto nesse valor baixo, pode ser o nosso filtro de palavras. O que fizemos no nosso classificador ele tira users de pessoas, alem de tirar letra maiscula e pontuação. Para melhorar isso e consequentimente melhorar a precisão do nosso classificador, poderiamos incluir o separador de emoji, retirar url, criar uma lista de palavras que com certeza não iria fazer sentido no assunto, e entre outros. Com isso nosso classificador poderia ter uma precisão bem maior e ser mais confiavel, e com mais tempo e verba, isso seria possivel, mas com os recursos inciais que tivemos, esse foi o melhor que foi possível fazer.

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
